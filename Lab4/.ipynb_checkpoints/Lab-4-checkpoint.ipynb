# %% [markdown]
# # Видобуток та збагачення структурованих даних

# %% [markdown]
# ### ТЕОРЕТИЧНА ЧАСТИНА ТА ПРИКЛАДИ

# %% [markdown]
# Для роботи з структурованими табличними даними, які розміщені в реляційній БД [SQLite](https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&cad=rja&uact=8&ved=2ahUKEwiUyMOv1orvAhWDK3cKHac9DyMQFjAAegQIBxAD&url=https%3A%2F%2Fru.wikipedia.org%2Fwiki%2FSQLite&usg=AOvVaw1s-RMK2VC2tXyDZxZXDYDo) в Python передбачена стандартна бібліотека [sqlite3](https://docs.python.org/3/library/sqlite3.html)

# %%
# підключення бібліотеки
import sqlite3

# %% [markdown]
# #### ПРИКЛАД ВИЛУЧЕННЯ ДАНИХ З БД
# Створити БД SQLite з ім'ям `FIT-3m`, та імпорувати в неї таблицю, що містить журнал групи `jornal`

# %%
# створюємо з'єднання з БД
conn = sqlite3.connect("FIT-3m.db")

# %% [markdown]
# [імпорт csv файла в sqlite через CLI](https://www.sqlitetutorial.net/sqlite-import-csv/)

# %%
# створюємо об'єкт `cursor`, що відповідає за реалізацію операцій з таблицями БД
cur = conn.cursor()

# %%
print(type(cur), end='\n\n')
print(dir(cur))

# %% [markdown]
# ##### виведемо ВСІ записи таблиці `jornal`

# %%
# створимо інстанс для операції `SELECT`
students_cur = cur.execute("SELECT * FROM jornal")

# будуємо список записів за допомогою метода `fetchall()`
students_list = students_cur.fetchall()

_ = [print(x) for x in students_list]

# %% [markdown]
# #### ПРИКЛАД ЗБАГАЧЕННЯ ДАНИХ З ЗОВНІШНЬОГО ДЖЕРЕЛА
#
# Додати до списка студентів їх оцінки за вступне тестування, які розташовані в csv файлі `test_result.csv`

# %% [markdown]
# імпортуємо `test_result.csv` в робочу БД як таблицю `test`
#
# [імпорт csv файла в sqlite через CLI](https://www.sqlitetutorial.net/sqlite-import-csv/)

# %% [markdown]
# ##### Cтворимо нову таблицю, яка буде містити вміст таблиці `jornal` та поле оцінок з таблиці `test`

# %%
# створимо вираз на побудову пустої таблиці `jornal_test` з відповідними полями
sql_stmt = "CREATE TABLE IF NOT EXISTS jornal_test \
              (Surname TEXT,         \
               Name TEXT,            \
               Email TEXT,           \
               Test_result INT);"

# виконаемо запит на створення таблиці
cur.execute(sql_stmt)

# перевіримо стан виконання операції - виведемо список таблиць
tables_list = cur.execute("SELECT name FROM sqlite_master WHERE type = 'table';")
tables_list.fetchall()

# %%
# створимо запит на об'єднання таблиць 'jornal' та 'test' по прізвищу студента
sql_stmt = "SELECT jornal.*, test.\"Оцінка/100\" FROM  \
            jornal LEFT JOIN test ON jornal.Surname = test.\"Ім\'я\" "

# для перевірки виконаємо і виведемо результати запиту
cur.execute(sql_stmt).fetchall()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-45-6ca9d9ffa997> in <module>
#       4
#       5 # для перевірки виконаємо і виведемо результати запиту
# ----> 6 cur.execute(sql_stmt).fetchall()
#
# OperationalError: no such table: jornal

# %%
# заповнимо пусту таблицю результатми  запиту на злиття
_ = cur.execute("INSERT INTO jornal_test " + sql_stmt)

# %%
# збережемо вміст нової таблиці в список
jornal_test_list = cur.execute("SELECT * FROM jornal_test").fetchall()

_ = [print(x) for x in jornal_test_list]

# %%
# завершимо всі транзакції
conn.commit()

# закріємо з'єднання
conn.close()

# %% [markdown]
# #### ПРИКЛАД  ДЕСКРИПТИВНОГО АНАЛІЗУ ДАНИХ
#
# Провести [попередній аналіз](https://ru.wikipedia.org/wiki/Описательная_статистика) отриманих даних з ціллю виявленя відхилень, помилок та інших непридатних даних.

# %% [markdown]
# Сведемо результати аналізу в таблицю, яка має наступний вигляд:
#
# №| Показчик | Значення
# :--:|:-------|-------:
# 1| кількість спостережень | xx
# 2| кількість пустих значень | xx
# 4| середній бал|  xx.x
# 5| максимальний бал | xx
# 6| мінімальний бал  | xx
# 7| стандартне відхилення | xx.x
# 8| розмах вариації  | xx

# %%
# підключимо бібліотеку 'numpy' і дамо їй аліас 'np'
import numpy as np

# %% [markdown]
# ознайомитись з призначенням, можливостями та основним функціями [бібліотеки numpy](https://numpy.org)

# %%
# перетворимо список студетів в numpay матрицю
jornal_test_arr = np.array(jornal_test_list)

# %%
print(type (jornal_test_arr), jornal_test_arr.shape)

# %%
# створимо масив с результатами тестів 
test_result = np.delete(jornal_test_arr, [0,1,2], 1)

# %%
# Значення 'None' - не є числом, то заміним його на 0
test_result[test_result == None] = 0

# %%
# будуємо словник з вихідними розрахунками
result_dict = {
    "кількість спостережень"   : len(test_result),
    "кількість пустих значень" : len(test_result) - np.count_nonzero(test_result),
    "середній бал"             : round(np.mean(test_result),1),
    "максимальний бал"         : np.max(test_result),
    "мінімальний бал"          : np.min(test_result[np.nonzero(test_result)]),
    "стандартне відхилення"    : round(np.std(test_result),1),
    "розмах вариації"          : np.max(test_result) - np.min(test_result[np.nonzero(test_result)]) 
    }

# %%
result_dict

# %%
# вивести шапку
print(
"""
=======================================
№  : ПОКАЗЧИК               : ЗНАЧЕННЯ     
=======================================
"""      
      )

# вивести результати аналізу датасета
i = 1
for key, value in result_dict.items():
    print (f'{i:<3} {key:<25}  {value}')
    i += 1

# %% [markdown]
# ### ІНДИВІДУАЛЬНЕ ЗАВДАННЯ

# %% [markdown]
# Користуючись результатами, що отримані в [Лабораторній роботі № 3](https://shkliarskiy.moodlecloud.com/mod/page/view.php?id=1193) виконати процедури видобутку, збагачення та попереднього аналізу даних.
#
# __Постановка__: В 3-й лабораторній роботі отримано показчик, що характеризує окрему властивість квартири (ціна, метраж та ін.).
# Необхідно:
# 1. Відобразити цей показчик на адресу квартири, яка знаходиться в файлі `street_name.csv`, тобто побудувати новий файл `street_flat_propery.csv` якій містить 2 колонки: _<назва вулиці> <ваш показчик>_
# 2. На основі цьго файлу зробити відповідну таблицю в _SQLite_ та збагатити цю дані в цій таблиці назвою району де розташована квартира (дані по районах додаються)
# 3. Провести попередній аналіз отриманих даних - вивести первинні статистики показчика по районах (_середне_ , _мінімальне_ , _максимальне_ і т.д. - див. приклад вище)

# %%
# Злиття файлу з показчиком та файлу з назвами вулиць в новий файл

YOUR_FILE = 'aprt_total_area.txt'
with open(YOUR_FILE) as f2, \
     open('street_name.csv') as f1, \
     open('street_flat_propery.csv', 'w') as f3:
    
    for x, y in zip(f1, f2):
        line = f'{x[:-1].strip()},{y[:-1].strip()}\n'
        print(line)
        f3.write(line)
# Out:
# street,area
#
# Омеляновича-Павленка,73.0
#
# ,0.0
#
# Ованеса Туманяна,100.0
#
# Петропавлівська,58.0
#
# Дніпровська,79.0
#
# Саксаганського,0.0
#
# Івана Мазепи,0.0
#
# Дніпровська,87.0
#
# Ділова,40.0
#
# Новодарницька,51.0
#
# Ревуцького,48.0
#
# Липківського,85.0
#
# Бендукідзе,76.0
#
# Введенська,56.0
#
# Виноградний,38.0
#
# Кайсарова,70.0
#
# Ахматової,103.0
#
# Радченка,0.0
#
# Дніпровська,69.0
#
# Ділова,0.0
#
# Бориспільська,50.0
#
# Болсуновська,64.0
#
# Українки,96.0
#
# Антонова,46.0
#
# Омеляновича-Павленка,44.0
#
# ,100.0
#
# Ованеса Туманяна,240.0
#
# Петропавлівська,0.0
#
# Дніпровська,75.0
#
# Саксаганського,78.0
#
# Івана Мазепи,126.0
#
# Дніпровська,93.0
#
# Ділова,63.0
#
# Новодарницька,44.0
#
# Ревуцького,0.0
#
# Липківського,52.0
#
# Бендукідзе,99.0
#
# Введенська,96.0
#
# Виноградний,65.0
#
# Кайсарова,50.0
#
# Ахматової,76.0
#
# Радченка,0.0
#
# Дніпровська,99.0
#
# Ділова,0.0
#
# Бориспільська,59.0
#
# Болсуновська,73.0
#
# Українки,62.0
#
# Антонова,76.0
#
# Науки,76.0
#
# Метрологічна,210.0
#
# Дружби Народів,33.0
#
# *** not found,0.0
#
# Драгомирова,62.0
#
# Данченка,0.0
#
# Кримська,110.0
#
# Новопольова,51.0
#
# Туполєва,44.0
#
# *** not found,91.0
#
# Дніпровська,28.0
#
# Перемоги,56.0
#
# Івана Федорова,0.0
#
# Братиславська,100.0
#
# *** not found,82.0
#
# Червоноткацька,122.0
#
# Златоустівська,45.0
#
# Бойченка,75.0
#
# Трускавецька,34.0
#
# Каховська,46.0
#
# Лобановського,100.0
#
# *** not found,99.0
#
# Курчатова,75.0
#
# Голосіївська,62.0
#
# Тираспольська,76.0
#
# Лаврська,210.0
#
# Правди,33.0
#
# Миколайчука,0.0
#
# Порика,62.0
#
# Червоноткацька,0.0
#
# Маккейна,110.0
#
# Йорданська,51.0
#
# Тютюнника,44.0
#
# Регенераторна,91.0
#
# Зарічна,28.0
#
# Заболотного,56.0
#
# Курнатовського,0.0
#
# Інститутська,100.0
#
# Маланюка,82.0
#
# Гречка,122.0
#
# Липківського,45.0
#
# Маккейна,75.0
#
# Григоренка,34.0
#
# Коновальця,46.0
#
# Закревського,100.0
#
# *** not found,99.0
#
# Старонаводницька,75.0
#
# Маланюка,62.0
#
# Заньковецької,72.0
#
# Кудрявська,0.0
#
# ,159.0
#
# Українки,76.0
#
# ,0.0
#
# Милославська,44.0
#
# Донця,95.0
#
# Верховинця,240.0
#
# Героїв Дніпра,36.0
#
# Каховська,50.0
#
# Каховська,71.0
#
# Вишняківська,0.0
#
# Липська,0.0
#
# Сверстюка,123.0
#
# Драгомирова,74.0
#
# Причальна,81.0
#
# Болсуновська,43.0
#
# Повітрофлотський,84.0
#
# Драгоманова,46.0
#
# Григоренка,55.0
#
# Дніпровська,136.0
#
# Жабаєва,0.0
#
# Філатова,136.0
#
# Правди,41.0
#
# Малопідвальна,71.0
#
# Бойчука,57.0
#
# Зарічна,149.0
#
# Предславинська,50.0
#
# Івана Мазепи,75.0
#
# Радченка,92.0
#
# Лабораторний,60.0
#
# Конєва,0.0
#
# Шаповала,0.0
#
# Дніпровська,55.0
#
# Клеманська,83.0
#
# Григоренка,55.0
#
# Туполєва,36.0
#
# Хмельницького,65.0
#
# Саперне Поле,112.0
#
# Героїв Сталінграда,50.0
#
# Дніпровська,68.0
#
# Тарасівська,85.0
#
# Краківська,51.0
#
# Юнацька,46.0
#
# Клеманська,207.0
#
# Героїв Сталінграда,130.0
#
# Драгомирова,81.0
#
# *** not found,41.0
#
# Драгоманова,50.0
#
# Українки,54.0
#
# Тимошенка,83.0
#
# Маяковського,81.0
#
# Дмитрівська,44.0
#
# Курбаса,90.0
#
# Комарова,79.0
#
# Драгоманова,43.0
#
# Драгомирова,51.0
#
# Моторний,0.0
#
# Милославська,0.0
#
# Бойчука,110.0
#
# Закревського,106.0
#
# Івана Федорова,72.0
#
# Філатова,122.0
#
# Перемоги,67.0
#
# Миропільська,273.0
#
# Григоренка,83.0
#
# Юнацька,45.0
#
# Вишгородська,0.0
#
# Жолудєва,0.0
#
# Павлівська,49.0
#
# Голосіївський,0.0
#
# Осокорська,183.0
#
# Вишгородська,0.0
#
# Драгомирова,76.0
#
# Тютюнника,160.0
#
# Маккейна,0.0
#
# Івана Мазепи,0.0
#
# Героїв Сталінграда,73.0
#
# Липківського,0.0
#
# *** not found,44.0
#
# Коновальця,75.0
#
# Максимовича,60.0
#
# Зарічна,34.0
#
# Голосіївська,65.0
#
# Ясинуватський,190.0
#
# *** not found,240.0
#
# Колоса,85.0
#
# Правди,48.0
#
# Велика Васильківська,75.0
#
# Голосіївський,60.0
#
# *** not found,0.0
#
# Бойчука,0.0
#
# Центральна,50.0
#
# Ясинуватський,71.0
#
# Райдужна,0.0
#
# Ломоносова,68.0
#
# ,44.0
#
# *** not found,48.0
#
# Гусовського,46.0
#
# Окіпної,0.0
#
# Багговутівська,0.0
#
# Дружби Народів,63.0
#
# Маккейна,71.0
#
# Маланюка,35.0
#
# Михайла Котельникова,48.0
#
# Героїв Севастополя,56.0
#
# Маланюка,206.0
#
# Саперне Поле,172.0
#
# Балтійський,45.0
#
# Кудрявська,85.0
#
# Перемоги,49.0
#
# Німанська,193.0
#
# Каховська,0.0
#
# Малопідвальна,43.0
#
# Невська,350.0
#
# Златоустівська,127.0
#
# ,0.0
#
# Берковецька,180.0
#
# Бажана,0.0
#
# Антоновича,0.0
#
# *** not found,60.0
#
# Гречка,60.0
#
# Микільсько-Слобідська,174.0
#
# Правди,73.0
#
# Тимошенка,93.0
#
# Павла Тичини,0.0
#
# Олевська,140.0
#
# Освіти,50.0
#
# Іллєнка,88.0
#
# Дніпровська,0.0
#
# Івана Мазепи,43.0
#
# Українки,72.0
#
# Данченка,247.0
#
# Драгомирова,250.0
#
# Тбіліський,67.0
#
# Каховська,81.0
#
# Ушинського,33.0
#
# Урлівська,0.0
#
# Світлицького,93.0
#
# Дніпровська,109.0
#
# Липківського,0.0
#
# Микільсько-Слобідська,55.0
#
# Лобановського,88.0
#
# Героїв Сталінграда,0.0
#
# Дніпровська,150.0
#
# Драгоманова,87.0
#
# Ахматової,275.0
#
# Саперне Поле,80.0
#
# Данченка,54.0
#
# Голосіївський,43.0
#
# *** not found,94.0
#
# Глибочицька,42.0
#
# Багговутівська,0.0
#
# Саксаганського,116.0
#
# Моторний,76.0
#
# Йорданська,59.0
#
# Саперне Поле,200.0
#
# Вернадського,70.0
#
# Курбаса,0.0
#
# Багговутівська,150.0
#
# Набережно-Рибальська,162.0
#
# Саксаганського,45.0
#
# Малиновського,62.0
#
# Протасів Яр,75.0
#
# Німанська,0.0
#
# Підвисоцького,70.0
#
# Зодчих,95.0
#
# Рокосовського,555.0
#
# Шовковична,0.0
#
# Крушельницької,93.0
#
# Новопольова,55.0
#
# Визволителів,102.0
#
# Сонячна,94.0
#
# Сікорського,41.0
#
# Радченка,0.0
#
# Бульварно-Кудрявська,0.0
#
# Кайсарова,0.0
#
# Дніпровська,67.0
#
# Перова,0.0
#
# Глушкова,31.0
#
# Рокосовського,87.0
#
# Саперно-Слобідська,82.0
#
# Миколи Кибальчича,50.0
#
# Миколи Ушакова,40.0
#
# Антоновича,70.0
#
# Богданівська,75.0
#
# ,96.0
#
# Сверстюка,56.0
#
# Ревуцького,43.0
#
# Ованеса Туманяна,119.0
#
# Саперне Поле,43.0
#
# Григоренка,22.0
#
# Гречка,105.0
#
# Богатирська,44.0
#
# Білоруська,69.0
#
# Регенераторна,45.0
#
# Вишняківська,95.0
#
# Гонгадзе,28.0
#
# Правди,40.0
#
# Кольцова,161.0
#
# Воскресенська,100.0
#
# Руставелі,65.0
#
# Голосіївський,213.0
#
# Комбінатна,62.0
#
# Салютна,63.0
#
# Маланюка,90.0
#
# Ромоданова,39.0
#
# Саперне Поле,73.0
#
# Сім’ї Кульженків,34.0
#
# Лабораторна,50.0
#
# Драгоманова,39.0
#
# ,55.0
#
# Кудрявська,58.0
#
# Краківська,52.0
#
# Кольцова,92.0
#
# Антоновича,68.0
#
# Лариси Руденко,0.0
#
# Івана Пулюя,65.0
#
# Українки,145.0
#
# Тютюнника,58.0
#
# Юрія Смолича,76.0
#
# Оболонський,46.0
#
# Курбаса,88.0
#
# Верховинця,0.0
#
# Зарічна,0.0
#
# Дніпровська,58.0
#
# Коломийський,52.0
#
# Правди,70.0
#
# Каховська,65.0
#
# Бойчука,47.0
#
# Правди,79.0
#
# Маккейна,34.0
#
# Перемоги,98.0
#
# Грушевського,50.0
#
# Срібнокільська,70.0
#
# Перемоги,45.0
#
# Урлівська,150.0
#
# Заболотного,66.0
#
# Максимовича,65.0
#
# Бажана,130.0
#
# Сікорського,70.0
#
# Курбаса,60.0
#
# Дніпровська,78.0
#
# Драгомирова,53.0
#
# ,65.0
#
# Антонова,0.0
#
# Бучми,69.0
#
# Кубанської України,61.0
#
# Дніпровська,81.0
#
# Панельна,57.0
#
# Коновальця,48.0
#
# Богатирська,47.0
#
# Оболонський,93.0
#
# Українки,49.0
#
# Бориса Гмирі,0.0
#
# Правди,72.0
#
# Центральна,65.0
#
# Преображенська,49.0
#
# Коновальця,31.0
#
# Українки,41.0
#
# *** not found,53.0
#
# Велика Васильківська,77.0
#
# Липківського,100.0
#
# Бойчука,55.0
#
# Васильківська,58.0
#
# Данькевича,52.0
#
# Богатирська,312.0
#
# Українки,87.0
#
# Гречка,145.0
#
# Редутна,50.0
#
# Бориса Гмирі,125.0
#
# Драгомирова,43.0
#
# Туполєва,130.0
#
# Кондратюка,81.0
#
# Мінський,208.0
#
# Княжий Затон,306.0
#
# Герцена,54.0
#
# Балтійський,105.0
#
# Ернста,69.0
#
# Шаповала,66.0
#
# Городецького,67.0
#
# Сім'ї Сосніних,46.0
#
# Івана Мазепи,104.0
#
# Червоноткацька,55.0
#
# *** not found,92.0
#
# Голосіївська,86.0
#
# *** not found,87.0
#
# Миколи Гулака,0.0
#
# Івана Федорова,0.0
#
# Саперне Поле,0.0
#
# Миколи Хвильового,0.0
#
# Паторжинського,0.0
#
# Наумовича,51.0
#
# Калнишевського,250.0
#
# Дніпровська,25.0
#
# Електриків,42.0
#
# Солом'янська,46.0
#
# Шевченка,127.0
#
# Озерна,46.0
#
# Григоренка,66.0
#
# Антонова,0.0
#
# Голосіївський,70.0
#
# Комарова,81.0
#
# Борщагівська,0.0
#
# Шевченка,0.0
#
# Максимовича,85.0
#
# Ковальський,79.0
#
# Малевича,83.0
#
# Мічуріна,38.0
#
# *** not found,160.0
#
# Балтійський,37.0
#
# Азербайджанська,0.0
#
# Зарічна,108.0
#
# Чавдар,150.0
#
# Правди,72.0
#
# Урлівська,0.0
#
# Бориспільська,41.0
#
# Поправки,53.0
#
# Бориспільська,43.0
#
# Ентузіастів,0.0
#
# Малоземельна,71.0
#
# Саксаганського,56.0
#
# Героїв Сталінграда,118.0
#
# Зодчих,80.0
#
# Калнишевського,85.0
#
# Філатова,104.0
#
# Старонаводницька,0.0
#
# Заболотного,0.0
#
# Правди,31.0
#
# *** not found,90.0
#
# Антоновича,104.0
#
# Шаповала,46.0
#
# Івана Федорова,103.0
#
# Деревлянська,38.0
#
# Вільямса,111.0
#
# Васильченка,90.0
#
# Предславинська,0.0
#
# Крайня,79.0
#
# Милославська,74.0
#
# Воскресенська,46.0
#
# Маланюка,49.0
#
# Дніпровська,76.0
#
# Пушкінська,103.0
#
# Набережно-Корчуватська,0.0
#
# Зарічна,110.0
#
# Тургенєвська,70.0
#
# Радченка,0.0
#
# Зарічна,60.0
#
# Метрологічна,93.0
#
# Йорданська,130.0
#
# Кольцова,25.0
#
# Максимовича,55.0
#
# Науки,171.0
#
# Саперно-Слобідська,43.0
#
# Шовковична,48.0
#
# Трускавецька,87.0
#
# Гавела,53.0
#
# Повітрофлотський,84.0
#
# Запорожця,46.0
#
# Маккейна,52.0
#
# Перемоги,91.0
#
# Щербаківського,65.0
#
# Зарічна,82.0
#
# Будищанська,88.0
#
# Жилянська,41.0
#
# Комбінатна,150.0
#
# Ревуцького,73.0
#
# Бородіна,81.0
#
# Руставелі,50.0
#
# Драгоманова,37.0
#
# Преображенська,60.0
#
# Депутатська,30.0
#
# Багговутівська,63.0
#
# *** not found,213.0
#
# Сікорського,0.0
#
# Драгомирова,0.0
#
# Коперніка,87.0
#
# Васильківська,68.0
#
# Глибочицька,103.0
#
# Чавдар,0.0
#
# Шовковична,91.0
#
# Дніпровська,64.0
#
# Антоновича,61.0
#
# ,94.0
#
# Славгородська,111.0
#
# Драгомирова,46.0
#
# Срібнокільська,40.0
#
# Харченка,70.0
#
# Окіпної,84.0
#
# Саперне Поле,53.0
#
# Олени Теліги,80.0
#
# Кондратюка,70.0
#
# Мечнікова,137.0
#
# Героїв Сталінграда,51.0
#
# Рибальська,52.0
#
# Березова,248.0
#
# Саперне Поле,52.0
#
# Антоновича,74.0
#
# Маккейна,108.0
#
# Лейпцизька,0.0
#
# Драгоманова,0.0
#
# Коновальця,55.0
#
# Василя Стуса,67.0
#
# Тютюнника,70.0
#
# Січових Стрільців,88.0
#
# Райдужна,24.0
#
# Закревського,0.0
#
# Тургенєвська,0.0
#
# Васильківська,46.0
#
# Зої Космодем'янської,250.0
#
# Радченка,37.0
#
# Сверстюка,51.0
#
# Милославська,61.0
#
# Метрологічна,110.0
#
# Деміївська,64.0
#
# Перемоги,0.0
#
# Вишгородська,110.0
#
# Маккейна,51.0
#
# ,70.0
#
# Перемоги,45.0
#
# Балтійський,0.0
#
# Звіринецька,70.0
#
# Ревуцького,0.0
#
# Правди,80.0
#
# Милославська,40.0
#
# Вербицького,54.0
#
# Новгородська,98.0
#
# Бажана,185.0
#
# Канівська,0.0
#
# Максимовича,73.0
#
# Донця,110.0
#
# Драгомирова,40.0
#
# Тираспольська,165.0
#
# Саксаганського,74.0
#
# Тираспольська,57.0
#
# Зарічна,70.0
#
# Гонгадзе,0.0
#
# Українки,78.0
#
# Світлицького,0.0
#
# Воробйова,92.0
#
# Каховська,54.0
#
# Глибочицька,85.0
#
# Білокур,350.0
#
# Балтійський,0.0
#
# Антоновича,170.0
#
# Кондратюка,48.0
#
# Гончара,55.0
#
# Ревуцького,230.0
#
# *** not found,0.0
#
# Драгоманова,0.0
#
# Сім’ї Кульженків,0.0
#
# Панельна,0.0
#
# Вільямса,29.0
#
# Голосіївська,67.0
#
# Оболонський,72.0
#
# Миколи Голего,55.0
#
# Дніпровська,0.0
#
# Малиновського,0.0
#
# Назарівська,62.0
#
# Гоголівська,130.0
#
# Дорогожицька,67.0
#
# Петропавлівська,42.0
#
# Грушевського,74.0
#
# Іллєнка,88.0
#
# Липківського,49.0
#
# Ушинського,42.0
#
# Польова,49.0
#
# Саперне Поле,55.0
#
# Панельна,42.0
#
# Коновальця,142.0
#
# Хмельницького,50.0
#
# Маккейна,32.0
#
# Антоновича,44.0
#
# Толстого,52.0
#
# Дружби Народів,156.0
#
# Оболонський,123.0
#
# Багговутівська,165.0
#
# Антонова,66.0
#
# Володимирська,0.0
#
# Українки,41.0
#
# Сім’ї Кульженків,42.0
#
# Коновальця,61.0
#
# Мирного,80.0
#
# Московська,119.0
#
# Жмеринська,53.0
#
# Бойчука,63.0
#
# Липківського,43.0
#
# Лабораторний,86.0
#
# Інститутська,120.0
#
# Українки,108.0
#
# Хрещатик,94.0
#
# Дніпровська,115.0
#
# Осокорська,0.0
#
# Саперне Поле,55.0
#
# Комарова,62.0
#
# Драгомирова,53.0
#
# Срібнокільська,0.0
#
# Чоколівський,122.0
#
# Звіринецька,90.0
#
# Вишгородська,55.0
#
# Драгомирова,40.0
#
# Героїв Сталінграда,46.0
#
# Будівельників,340.0
#
# Іллєнка,41.0
#
# Урлівська,47.0
#
# Сормовська,55.0
#
# Правди,79.0
#
# Верховинна,65.0
#
# Вербицького,32.0
#
# *** not found,63.0
#
# Велика Васильківська,50.0
#
# Бойчука,36.0
#
# Лобановського,35.0
#
# Миколи Шепелєва,52.0
#
# Кропивницького,50.0
#
# Трускавецька,165.0
#
# Голосіївська,71.0
#
# Маланюка,110.0
#
# Драгомирова,102.0
#
# Юнацька,80.0
#
# Максимовича,60.0
#
# Комарова,70.0
#
# Багговутівська,80.0
#
# ,84.0
#
# Костанайська,72.0
#
# Срібнокільська,96.0
#
# Курчатова,32.0
#
# Гусовського,113.0
#
# Українки,119.0
#
# Драгоманова,61.0
#
# Дніпровська,75.0
#
# Заболотного,0.0
#
# Заболотного,82.0
#
# Перемоги,98.0
#
# Сверстюка,32.0
#
# Липківського,37.0
#
# Маккейна,96.0
#
# Дніпровська,74.0
#
# Волгоградська,54.0
#
# Новопольова,88.0
#
# Драгоманова,0.0
#
# Лебедєва,65.0
#
# *** not found,50.0
#
# Драгомирова,100.0
#
# Лейпцизька,125.0
#
# Глибочицька,55.0
#
# Салютна,55.0
#
# Метрологічна,49.0
#
# Північно-Сирецька,0.0
#
# Правди,55.0
#
# Вернадського,0.0
#
# Пчілки,130.0
#
# Лейпцизька,40.0
#
# Басейна,56.0
#
# Шаповала,75.0
#
# Бережанська,98.0
#
# Бойчука,0.0
#
# Перемоги,51.0
#
# Івана Федорова,32.0
#
# Антоновича,308.0
#
# Вільямса,30.0
#
# Бойчука,90.0
#
# Перемоги,61.0
#
# Ковпака,105.0
#
# Русанівський,32.0
#
# Українки,27.0
#
# Празька,37.0
#
# Гончара,76.0
#
# Маккейна,75.0
#
# Балтійський,65.0
#
# Білоруська,114.0
#
# Драгоманова,152.0
#
# Липківського,115.0
#
# Новогоспітальна,89.0
#
# Радченка,70.0
#
# Богомольця,0.0
#
# Донця,0.0
#
# Оболонський,85.0
#
# Щекавицька,83.0
#
# Пожарського,119.0
#
# Полкова,100.0
#
# Донця,42.0
#
# Палладіна,44.0
#
# Бойчука,262.0
#
# Липківського,125.0
#
# Павлівська,35.0
#
# Івашкевича,51.0
#
# Іскрівська,66.0
#
# Максимовича,68.0
#
# *** not found,70.0
#
# Драгомирова,113.0
#
# Теремківська,0.0
#
# Осокорська,108.0
#
# Дмитрівська,46.0
#
# Кондратюка,60.0
#
# Регенераторна,125.0
#
# ,58.0
#
# Глибочицька,0.0
#
# Героїв Сталінграда,120.0
#
# Борщагівська,68.0
#
# Ревуцького,42.0
#
# Юнацька,69.0
#
# Заболотного,86.0
#
# Автозаводська,32.0
#
# Заболотного,0.0
#
# Саксаганського,52.0
#
# Зарічна,92.0
#
# *** not found,60.0
#
# Невська,0.0
#
# Героїв Сталінграда,189.0
#
# Вишняківська,59.0
#
# Драгомирова,69.0
#
# Драгомирова,48.0
#
# Гавела,62.0
#
# Здолбунівська,87.0
#
# Драгомирова,83.0
#
# Мечнікова,65.0
#
# *** not found,37.0
#
# Максимовича,56.0
#
# Багговутівська,64.0
#
# Шолуденка,78.0
#
# Щекавицька,64.0
#
# Коласа,37.0
#
# *** not found,117.0
#
# *** not found,45.0
#
# Перемоги,42.0
#
# *** not found,115.0
#
# Наумова,0.0
#
# Перемоги,76.0
#
# Велика Васильківська,115.0
#
# Червоноткацька,0.0
#
# Вишгородська,0.0

# %% [markdown]
# #### імпортувати в БД отриманий файл 'street_flat_propery.csv' через CLI
# - __sqlite3 districts.db__ - запустити SQLite та відкрити БД
# - __.mode csv__ - перевести БД для роботи з csv-файлами
# - __.import street_flat_propery.csv street_flat_propery__ - створює таблицю _street_flat_propery_ та завантажує в неї вміст файлу _street_flat_propery.csv_
# - __SELECT * FROM street_flat_propery LIMIT 10;__ - вивести 10 записів для перевірки
# - __.quit__ - завершити роботу з CLI SQLite

# %%
# Підключитись до БД 'districts.db' в якій є прив'язка вулиць до районів 
conn = sqlite3.connect("districts.db")

# створити відповідний курсор
cur = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-f5ddf15b462a> in <module>
#       1 # Підключитись до БД 'districts.db' в якій є прив'язка вулиць до районів
# ----> 2 conn = sqlite3.connect("districts.db")
#       3
#       4 # створити відповідний курсор
#       5 cur = conn.cursor()
#
# NameError: name 'sqlite3' is not defined

# %%
# для перевірки виведіть 10 записів з таблиці 'street_district'
напишить код ...

# %%
# побудувати запит на створення таблиці 'result' з 3-ма полями:
#     district - текстове
#     street - текстове
#     property - числове
stmt = напишить код ...

# %%
# виконати запит
cur.execute(stmt)

# %%
# перевірити схему таблиці
cur.execute ("SELECT name FROM PRAGMA_TABLE_INFO('result');").fetchall()

# %%
# створити запит на злиття таблиці 'street_flat_propery' та 'street_district' 
# по полю 'street'
stmt_join = напишить код ...

# %%
# перевірити запит
_ = cur.execute(stmt_join).fetchall()

# %%
# створити запит для наповнення таблиці `result` результатом запиту на об'єднання
stmt_insert = напишить код ..

# %%
# виконати запит на заповнення
cur.execute(stmt_insert)

# %%
# сберегти вміст створеної таблиці у вигляді списка
result_list = напишить код ...

# %%
# підключення бібліотеки
import sqlite3

# Підключитись до БД 'districts.db' в якій є прив'язка вулиць до районів 
conn = sqlite3.connect("districts.db")

# створити відповідний курсор
cur = conn.cursor()
print(type(cur), end='\n\n')
print(dir(cur))

# для перевірки виведіть 10 записів з таблиці 'street_district'
apart_cur = cur.execute("SELECT * FROM street_district LIMIT 10")
apart_list = apart_cur.fetchall()
_ = [print(x) for x in apart_list]

# побудувати запит на створення таблиці 'result' з 3-ма полями:
#     district - текстове
#     street - текстове
#     property - числове
stmt = "CREATE TABLE IF NOT EXISTS result \
              (district TEXT,         \
               street TEXT,            \
               property INT);"

# виконати запит
cur.execute(stmt)

# перевірити схему таблиці
cur.execute ("SELECT name FROM PRAGMA_TABLE_INFO('result');").fetchall()

# створити запит на злиття таблиці 'street_flat_propery' та 'street_district' по полю 'street'
stmt_join = "SELECT street_district.district, street_flat_propery.* FROM \
             street_flat_propery LEFT JOIN street_district ON street_flat_propery.street = street_district.street"

# перевірити запит
cur.execute(stmt_join).fetchall()

# створити запит для наповнення таблиці `result` результатом запиту на об'єднання
stmt_insert = ("INSERT INTO result " + stmt_join)

# виконати запит на заповнення
cur.execute(stmt_insert)

# сберегти вміст створеної таблиці у вигляді списка
result_list = cur.execute("SELECT * FROM result").fetchall()

_ = [print(x) for x in result_list]

# завершимо всі транзакції
conn.commit()

# закріємо з'єднання
conn.close()
# Out:
# <class 'sqlite3.Cursor'>
#
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'arraysize', 'close', 'connection', 'description', 'execute', 'executemany', 'executescript', 'fetchall', 'fetchmany', 'fetchone', 'lastrowid', 'row_factory', 'rowcount', 'setinputsizes', 'setoutputsize']
# ('9-го Травня', 'вулиця', 'Святошинський')
# ('Абрикосова', 'вулиця', 'Оболонський')
# ('Абрикосова', 'вулиця', 'Дарницький')
# ('Абрикосова', 'вулиця', 'Подільський')
# ('Августина Волошина', 'вулиця', 'Солом’янський')
# ('Авдєєнка Генерала', 'вулиця', 'Святошинський')
# ('Автозаводська', 'вулиця', 'Оболонський')
# ('Автозаводський ', 'провулок', 'Оболонський')
# ('Автопаркова', 'вулиця', 'Дарницький')
# ('Авторемонтна', 'вулиця', "Солом'янський")
# (None, 'Омеляновича-Павленка', 73)
# (None, None, 0)
# (None, 'Ованеса Туманяна', 100)
# ('Оболонський', 'Петропавлівська', 58)
# ('Подільський', 'Петропавлівська', 58)
# ('Оболонський', 'Дніпровська', 79)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 0)
# (None, 'Івана Мазепи', 0)
# ('Оболонський', 'Дніпровська', 87)
# ('Голосіївський, Печерський', 'Ділова', 40)
# (None, 'Новодарницька', 51)
# ('Дарницький', 'Ревуцького', 48)
# (None, 'Липківського', 85)
# (None, 'Бендукідзе', 76)
# ('Подільський', 'Введенська', 56)
# ('Печерський', 'Виноградний', 38)
# ("Голосіївський,Солом'янський", 'Кайсарова', 70)
# (None, 'Ахматової', 103)
# (None, 'Радченка', 0)
# ('Оболонський', 'Дніпровська', 69)
# ('Голосіївський, Печерський', 'Ділова', 0)
# ('Дарницький', 'Бориспільська', 50)
# ('Печерський', 'Болсуновська', 64)
# (None, 'Українки', 96)
# (None, 'Антонова', 46)
# (None, 'Омеляновича-Павленка', 44)
# (None, None, 100)
# (None, 'Ованеса Туманяна', 240)
# ('Оболонський', 'Петропавлівська', 0)
# ('Подільський', 'Петропавлівська', 0)
# ('Оболонський', 'Дніпровська', 75)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 78)
# (None, 'Івана Мазепи', 126)
# ('Оболонський', 'Дніпровська', 93)
# ('Голосіївський, Печерський', 'Ділова', 63)
# (None, 'Новодарницька', 44)
# ('Дарницький', 'Ревуцького', 0)
# (None, 'Липківського', 52)
# (None, 'Бендукідзе', 99)
# ('Подільський', 'Введенська', 96)
# ('Печерський', 'Виноградний', 65)
# ("Голосіївський,Солом'янський", 'Кайсарова', 50)
# (None, 'Ахматової', 76)
# (None, 'Радченка', 0)
# ('Оболонський', 'Дніпровська', 99)
# ('Голосіївський, Печерський', 'Ділова', 0)
# ('Дарницький', 'Бориспільська', 59)
# ('Печерський', 'Болсуновська', 73)
# (None, 'Українки', 62)
# (None, 'Антонова', 76)
# ('Голосіївський', 'Науки', 76)
# ('Голосіївський', 'Метрологічна', 210)
# ('Печерський', 'Дружби Народів', 33)
# (None, '*** not found', 0)
# (None, 'Драгомирова', 62)
# (None, 'Данченка', 0)
# ('Голосіївський', 'Кримська', 110)
# ("Солом'янський", 'Новопольова', 51)
# (None, 'Туполєва', 44)
# (None, '*** not found', 91)
# ('Оболонський', 'Дніпровська', 28)
# ('Святошинський', 'Перемоги', 56)
# ('Шевченківський', 'Перемоги', 56)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 56)
# (None, 'Івана Федорова', 0)
# ('Деснянський, Дніпровський', 'Братиславська', 100)
# (None, '*** not found', 82)
# (None, 'Червоноткацька', 122)
# (None, 'Златоустівська', 45)
# (None, 'Бойченка', 75)
# ('Дарницький', 'Трускавецька', 34)
# ('Дніпровський', 'Каховська', 46)
# (None, 'Лобановського', 100)
# (None, '*** not found', 99)
# (None, 'Курчатова', 75)
# ('Голосіївський', 'Голосіївська', 62)
# ('Голосіївський', 'Голосіївська', 62)
# ('Подільський', 'Тираспольська', 76)
# ('Печерський', 'Лаврська', 210)
# ('Подільський', 'Правди', 33)
# (None, 'Миколайчука', 0)
# (None, 'Порика', 62)
# (None, 'Червоноткацька', 0)
# (None, 'Маккейна', 110)
# ('Оболонський', 'Йорданська', 51)
# (None, 'Тютюнника', 44)
# ('Дніпровський', 'Регенераторна', 91)
# ('Дарницький', 'Зарічна', 28)
# (None, 'Заболотного', 56)
# ('Дніпровський, Деснянський', 'Курнатовського', 0)
# ('Печерський', 'Інститутська', 100)
# (None, 'Маланюка', 82)
# (None, 'Гречка', 122)
# (None, 'Липківського', 45)
# (None, 'Маккейна', 75)
# (None, 'Григоренка', 34)
# (None, 'Коновальця', 46)
# (None, 'Закревського', 100)
# (None, '*** not found', 99)
# ('Печерський', 'Старонаводницька', 75)
# (None, 'Маланюка', 62)
# ('Печерський', 'Заньковецької', 72)
# ('Шевченківський', 'Кудрявська', 0)
# (None, None, 159)
# (None, 'Українки', 76)
# (None, None, 0)
# ('Деснянський', 'Милославська', 44)
# (None, 'Донця', 95)
# (None, 'Верховинця', 240)
# ('Оболонський', 'Героїв Дніпра', 36)
# ('Дніпровський', 'Каховська', 50)
# ('Дніпровський', 'Каховська', 71)
# ('Дарницький', 'Вишняківська', 0)
# (None, 'Липська', 0)
# (None, 'Сверстюка', 123)
# (None, 'Драгомирова', 74)
# ('Дарницький', 'Причальна', 81)
# ('Печерський', 'Болсуновська', 43)
# ("Шевченківський, Солом'янський", 'Повітрофлотський', 84)
# ('Дарницький', 'Драгоманова', 46)
# (None, 'Григоренка', 55)
# ('Оболонський', 'Дніпровська', 136)
# (None, 'Жабаєва', 0)
# (None, 'Філатова', 136)
# ('Подільський', 'Правди', 41)
# ('Шевченківський', 'Малопідвальна', 71)
# (None, 'Бойчука', 57)
# ('Дарницький', 'Зарічна', 149)
# ('Печерський', 'Предславинська', 50)
# (None, 'Івана Мазепи', 75)
# (None, 'Радченка', 92)
# ('Печерський', 'Лабораторний', 60)
# (None, 'Конєва', 0)
# (None, 'Шаповала', 0)
# ('Оболонський', 'Дніпровська', 55)
# ('Дарницький', 'Клеманська', 83)
# (None, 'Григоренка', 55)
# (None, 'Туполєва', 36)
# (None, 'Хмельницького', 65)
# ('Печерський', 'Саперне Поле', 112)
# ('Оболонський', 'Героїв Сталінграда', 50)
# ('Оболонський', 'Дніпровська', 68)
# ('Голосіївський', 'Тарасівська', 85)
# ('Дніпровський', 'Краківська', 51)
# ('Святошинський', 'Юнацька', 46)
# ("Солом'янський", 'Юнацька', 46)
# ('Дарницький', 'Клеманська', 207)
# ('Оболонський', 'Героїв Сталінграда', 130)
# (None, 'Драгомирова', 81)
# (None, '*** not found', 41)
# ('Дарницький', 'Драгоманова', 50)
# (None, 'Українки', 54)
# (None, 'Тимошенка', 83)
# ('Деснянський', 'Маяковського', 81)
# ('Подільський', 'Дмитрівська', 44)
# ('Шевченківський', 'Дмитрівська', 44)
# (None, 'Курбаса', 90)
# (None, 'Комарова', 79)
# ('Дарницький', 'Драгоманова', 43)
# (None, 'Драгомирова', 51)
# (None, 'Моторний', 0)
# ('Деснянський', 'Милославська', 0)
# (None, 'Бойчука', 110)
# (None, 'Закревського', 106)
# (None, 'Івана Федорова', 72)
# (None, 'Філатова', 122)
# ('Святошинський', 'Перемоги', 67)
# ('Шевченківський', 'Перемоги', 67)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 67)
# ('Деснянський, Дніпровський', 'Миропільська', 273)
# (None, 'Григоренка', 83)
# ('Святошинський', 'Юнацька', 45)
# ("Солом'янський", 'Юнацька', 45)
# ('Подільський, Оболонський', 'Вишгородська', 0)
# ('Святошинський', 'Жолудєва', 0)
# ('Шевченківський', 'Павлівська', 49)
# ('Голосіївський', 'Голосіївський', 0)
# ('Голосіївський', 'Голосіївський', 0)
# ('Дарницький', 'Осокорська', 183)
# ('Подільський, Оболонський', 'Вишгородська', 0)
# (None, 'Драгомирова', 76)
# (None, 'Тютюнника', 160)
# (None, 'Маккейна', 0)
# (None, 'Івана Мазепи', 0)
# ('Оболонський', 'Героїв Сталінграда', 73)
# (None, 'Липківського', 0)
# (None, '*** not found', 44)
# (None, 'Коновальця', 75)
# ('Святошинський', 'Максимовича', 60)
# ('Дарницький', 'Зарічна', 34)
# ('Голосіївський', 'Голосіївська', 65)
# ('Голосіївський', 'Голосіївська', 65)
# ('Голосіївський', 'Ясинуватський', 190)
# (None, '*** not found', 240)
# (None, 'Колоса', 85)
# ('Подільський', 'Правди', 48)
# ('Голосіївський, Шевченківський, Печерський', 'Велика Васильківська', 75)
# ('Голосіївський', 'Голосіївський', 60)
# ('Голосіївський', 'Голосіївський', 60)
# (None, '*** not found', 0)
# (None, 'Бойчука', 0)
# ('Дніпровський', 'Центральна', 50)
# ('Оболонський', 'Центральна', 50)
# ('Шевченківський', 'Центральна', 50)
# ('Голосіївський', 'Ясинуватський', 71)
# ('Дніпровський', 'Райдужна', 0)
# ('Голосіївський', 'Ломоносова', 68)
# (None, None, 44)
# (None, '*** not found', 48)
# ('Печерський', 'Гусовського', 46)
# (None, 'Окіпної', 0)
# ('Шевченківський', 'Багговутівська', 0)
# ('Печерський', 'Дружби Народів', 63)
# (None, 'Маккейна', 71)
# (None, 'Маланюка', 35)
# (None, 'Михайла Котельникова', 48)
# ("Солом'янський", 'Героїв Севастополя', 56)
# (None, 'Маланюка', 206)
# ('Печерський', 'Саперне Поле', 172)
# ('Оболонський', 'Балтійський', 45)
# ('Шевченківський', 'Кудрявська', 85)
# ('Святошинський', 'Перемоги', 49)
# ('Шевченківський', 'Перемоги', 49)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 49)
# ('Печерський', 'Німанська', 193)
# ('Дніпровський', 'Каховська', 0)
# ('Шевченківський', 'Малопідвальна', 43)
# (None, 'Невська', 350)
# (None, 'Златоустівська', 127)
# (None, None, 0)
# ('Святошинський', 'Берковецька', 180)
# (None, 'Бажана', 0)
# ('Голосіївський, Печерський', 'Антоновича', 0)
# (None, '*** not found', 60)
# (None, 'Гречка', 60)
# ('Дніпровський', 'Микільсько-Слобідська', 174)
# ('Подільський', 'Правди', 73)
# (None, 'Тимошенка', 93)
# (None, 'Павла Тичини', 0)
# ('Святошинський', 'Олевська', 140)
# ("Солом'янський", 'Освіти', 50)
# (None, 'Іллєнка', 88)
# ('Оболонський', 'Дніпровська', 0)
# (None, 'Івана Мазепи', 43)
# (None, 'Українки', 72)
# (None, 'Данченка', 247)
# (None, 'Драгомирова', 250)
# (None, 'Тбіліський', 67)
# ('Дніпровський', 'Каховська', 81)
# ("Солом'янський", 'Ушинського', 33)
# ("Солом'янський", 'Ушинського', 33)
# ('Дарницький', 'Урлівська', 0)
# ('Подільський', 'Світлицького', 93)
# ('Оболонський', 'Дніпровська', 109)
# (None, 'Липківського', 0)
# ('Дніпровський', 'Микільсько-Слобідська', 55)
# (None, 'Лобановського', 88)
# ('Оболонський', 'Героїв Сталінграда', 0)
# ('Оболонський', 'Дніпровська', 150)
# ('Дарницький', 'Драгоманова', 87)
# (None, 'Ахматової', 275)
# ('Печерський', 'Саперне Поле', 80)
# (None, 'Данченка', 54)
# ('Голосіївський', 'Голосіївський', 43)
# ('Голосіївський', 'Голосіївський', 43)
# (None, '*** not found', 94)
# ('Шевченківський', 'Глибочицька', 42)
# ('Шевченківський', 'Багговутівська', 0)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 116)
# (None, 'Моторний', 76)
# ('Оболонський', 'Йорданська', 59)
# ('Печерський', 'Саперне Поле', 200)
# (None, 'Вернадського', 70)
# (None, 'Курбаса', 0)
# ('Шевченківський', 'Багговутівська', 150)
# ('Подільський', 'Набережно-Рибальська', 162)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 45)
# (None, 'Малиновського', 62)
# ("Солом'янський", 'Протасів Яр', 75)
# ('Печерський', 'Німанська', 0)
# (None, 'Підвисоцького', 70)
# ('Святошинський', 'Зодчих', 95)
# (None, 'Рокосовського', 555)
# ('Печерський', 'Шовковична', 0)
# (None, 'Крушельницької', 93)
# ("Солом'янський", 'Новопольова', 55)
# ('Дніпровський', 'Визволителів', 102)
# ('Дніпровський', 'Сонячна', 94)
# ('Шевченківський', 'Сонячна', 94)
# (None, 'Сікорського', 41)
# (None, 'Радченка', 0)
# ('Шевченківський', 'Бульварно-Кудрявська', 0)
# ("Голосіївський,Солом'янський", 'Кайсарова', 0)
# ('Оболонський', 'Дніпровська', 67)
# ('Дніпровський', 'Перова', 0)
# (None, 'Глушкова', 31)
# (None, 'Рокосовського', 87)
# ('Голосіївський', 'Саперно-Слобідська', 82)
# (None, 'Миколи Кибальчича', 50)
# (None, 'Миколи Ушакова', 40)
# ('Голосіївський, Печерський', 'Антоновича', 70)
# ("Солом'янський", 'Богданівська', 75)
# (None, None, 96)
# (None, 'Сверстюка', 56)
# ('Дарницький', 'Ревуцького', 43)
# (None, 'Ованеса Туманяна', 119)
# ('Печерський', 'Саперне Поле', 43)
# (None, 'Григоренка', 22)
# (None, 'Гречка', 105)
# ('Оболонський', 'Богатирська', 44)
# ('Шевченківський', 'Білоруська', 69)
# ('Дніпровський', 'Регенераторна', 45)
# ('Дарницький', 'Вишняківська', 95)
# (None, 'Гонгадзе', 28)
# ('Подільський', 'Правди', 40)
# ('Святошинський', 'Кольцова', 161)
# ('Дніпровський', 'Воскресенська', 100)
# (None, 'Руставелі', 65)
# ('Голосіївський', 'Голосіївський', 213)
# ('Голосіївський', 'Голосіївський', 213)
# ('Дніпровський', 'Комбінатна', 62)
# ('Шевченківський', 'Салютна', 63)
# (None, 'Маланюка', 90)
# (None, 'Ромоданова', 39)
# ('Печерський', 'Саперне Поле', 73)
# (None, 'Сім’ї Кульженків', 34)
# ('Голосіївський, Печерський', 'Лабораторна', 50)
# ('Дарницький', 'Драгоманова', 39)
# (None, None, 55)
# ('Шевченківський', 'Кудрявська', 58)
# ('Дніпровський', 'Краківська', 52)
# ('Святошинський', 'Кольцова', 92)
# ('Голосіївський, Печерський', 'Антоновича', 68)
# (None, 'Лариси Руденко', 0)
# (None, 'Івана Пулюя', 65)
# (None, 'Українки', 145)
# (None, 'Тютюнника', 58)
# (None, 'Юрія Смолича', 76)
# ('Оболонський', 'Оболонський', 46)
# (None, 'Курбаса', 88)
# (None, 'Верховинця', 0)
# ('Дарницький', 'Зарічна', 0)
# ('Оболонський', 'Дніпровська', 58)
# ('Голосіївський', 'Коломийський', 52)
# ('Подільський', 'Правди', 70)
# ('Дніпровський', 'Каховська', 65)
# (None, 'Бойчука', 47)
# ('Подільський', 'Правди', 79)
# (None, 'Маккейна', 34)
# ('Святошинський', 'Перемоги', 98)
# ('Шевченківський', 'Перемоги', 98)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 98)
# (None, 'Грушевського', 50)
# ('Дарницький', 'Срібнокільська', 70)
# ('Святошинський', 'Перемоги', 45)
# ('Шевченківський', 'Перемоги', 45)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 45)
# ('Дарницький', 'Урлівська', 150)
# (None, 'Заболотного', 66)
# ('Святошинський', 'Максимовича', 65)
# (None, 'Бажана', 130)
# (None, 'Сікорського', 70)
# (None, 'Курбаса', 60)
# ('Оболонський', 'Дніпровська', 78)
# (None, 'Драгомирова', 53)
# (None, None, 65)
# (None, 'Антонова', 0)
# (None, 'Бучми', 69)
# ('Деснянський', 'Кубанської України', 61)
# ('Оболонський', 'Дніпровська', 81)
# (None, 'Панельна', 57)
# (None, 'Коновальця', 48)
# ('Оболонський', 'Богатирська', 47)
# ('Оболонський', 'Оболонський', 93)
# (None, 'Українки', 49)
# (None, 'Бориса Гмирі', 0)
# ('Подільський', 'Правди', 72)
# ('Дніпровський', 'Центральна', 65)
# ('Оболонський', 'Центральна', 65)
# ('Шевченківський', 'Центральна', 65)
# ("Солом'янський", 'Преображенська', 49)
# (None, 'Коновальця', 31)
# (None, 'Українки', 41)
# (None, '*** not found', 53)
# ('Голосіївський, Шевченківський, Печерський', 'Велика Васильківська', 77)
# (None, 'Липківського', 100)
# (None, 'Бойчука', 55)
# ('Голосіївський', 'Васильківська', 58)
# (None, 'Данькевича', 52)
# ('Оболонський', 'Богатирська', 312)
# (None, 'Українки', 87)
# (None, 'Гречка', 145)
# ('Печерський', 'Редутна', 50)
# (None, 'Бориса Гмирі', 125)
# (None, 'Драгомирова', 43)
# (None, 'Туполєва', 130)
# (None, 'Кондратюка', 81)
# ('Оболонський', 'Мінський', 208)
# ('Подільський', 'Мінський', 208)
# ('Дарницький', 'Княжий Затон', 306)
# ('Шевченківський', 'Герцена', 54)
# ('Шевченківський', 'Герцена', 54)
# ('Шевченківський', 'Герцена', 54)
# ('Оболонський', 'Балтійський', 105)
# (None, 'Ернста', 69)
# (None, 'Шаповала', 66)
# (None, 'Городецького', 67)
# (None, "Сім'ї Сосніних", 46)
# (None, 'Івана Мазепи', 104)
# (None, 'Червоноткацька', 55)
# (None, '*** not found', 92)
# ('Голосіївський', 'Голосіївська', 86)
# ('Голосіївський', 'Голосіївська', 86)
# (None, '*** not found', 87)
# (None, 'Миколи Гулака', 0)
# (None, 'Івана Федорова', 0)
# ('Печерський', 'Саперне Поле', 0)
# (None, 'Миколи Хвильового', 0)
# ('Шевченківський', 'Паторжинського', 0)
# (None, 'Наумовича', 51)
# (None, 'Калнишевського', 250)
# ('Оболонський', 'Дніпровська', 25)
# ('Подільський', 'Електриків', 42)
# ('Подільський', 'Електриків', 42)
# ("Солом'янський", "Солом'янська", 46)
# ("Солом'янський", "Солом'янська", 46)
# ('Дарницький', 'Шевченка', 127)
# ('Дарницький', 'Шевченка', 127)
# ('Деснянський', 'Шевченка', 127)
# ("Солом'янський", 'Шевченка', 127)
# ("Солом'янський", 'Шевченка', 127)
# ('Дарницький', 'Озерна', 46)
# ('Оболонський', 'Озерна', 46)
# ('Святошинський (СТ "Нивки")', 'Озерна', 46)
# ("Солом'янський", 'Озерна', 46)
# (None, 'Григоренка', 66)
# (None, 'Антонова', 0)
# ('Голосіївський', 'Голосіївський', 70)
# ('Голосіївський', 'Голосіївський', 70)
# (None, 'Комарова', 81)
# ("Солом'янський, Шевченківський ", 'Борщагівська', 0)
# ('Дарницький', 'Шевченка', 0)
# ('Дарницький', 'Шевченка', 0)
# ('Деснянський', 'Шевченка', 0)
# ("Солом'янський", 'Шевченка', 0)
# ("Солом'янський", 'Шевченка', 0)
# ('Святошинський', 'Максимовича', 85)
# ("Солом'янський", 'Ковальський', 79)
# (None, 'Малевича', 83)
# ('Деснянський', 'Мічуріна', 38)
# ('Оболонський', 'Мічуріна', 38)
# ('Печерський', 'Мічуріна', 38)
# ('Печерський', 'Мічуріна', 38)
# ("Солом'янський", 'Мічуріна', 38)
# (None, '*** not found', 160)
# ('Оболонський', 'Балтійський', 37)
# ('Дніпровський', 'Азербайджанська', 0)
# ('Дарницький', 'Зарічна', 108)
# (None, 'Чавдар', 150)
# ('Подільський', 'Правди', 72)
# ('Дарницький', 'Урлівська', 0)
# ('Дарницький', 'Бориспільська', 41)
# (None, 'Поправки', 53)
# ('Дарницький', 'Бориспільська', 43)
# ('Дніпровський', 'Ентузіастів', 0)
# ('Дарницький', 'Малоземельна', 71)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 56)
# ('Оболонський', 'Героїв Сталінграда', 118)
# ('Святошинський', 'Зодчих', 80)
# (None, 'Калнишевського', 85)
# (None, 'Філатова', 104)
# ('Печерський', 'Старонаводницька', 0)
# (None, 'Заболотного', 0)
# ('Подільський', 'Правди', 31)
# (None, '*** not found', 90)
# ('Голосіївський, Печерський', 'Антоновича', 104)
# (None, 'Шаповала', 46)
# (None, 'Івана Федорова', 103)
# ('Шевченківський', 'Деревлянська', 38)
# (None, 'Вільямса', 111)
# ("Солом'янський", 'Васильченка', 90)
# ('Печерський', 'Предславинська', 0)
# ('Деснянський', 'Крайня', 79)
# ('Деснянський', 'Милославська', 74)
# ('Дніпровський', 'Воскресенська', 46)
# (None, 'Маланюка', 49)
# ('Оболонський', 'Дніпровська', 76)
# ('Шевченківський', 'Пушкінська', 103)
# ('Голосіївський', 'Набережно-Корчуватська', 0)
# ('Дарницький', 'Зарічна', 110)
# ('Шевченківський', 'Тургенєвська', 70)
# (None, 'Радченка', 0)
# ('Дарницький', 'Зарічна', 60)
# ('Голосіївський', 'Метрологічна', 93)
# ('Оболонський', 'Йорданська', 130)
# ('Святошинський', 'Кольцова', 25)
# ('Святошинський', 'Максимовича', 55)
# ('Голосіївський', 'Науки', 171)
# ('Голосіївський', 'Саперно-Слобідська', 43)
# ('Печерський', 'Шовковична', 48)
# ('Дарницький', 'Трускавецька', 87)
# (None, 'Гавела', 53)
# ("Шевченківський, Солом'янський", 'Повітрофлотський', 84)
# (None, 'Запорожця', 46)
# (None, 'Маккейна', 52)
# ('Святошинський', 'Перемоги', 91)
# ('Шевченківський', 'Перемоги', 91)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 91)
# (None, 'Щербаківського', 65)
# ('Дарницький', 'Зарічна', 82)
# ('Деснянський', 'Будищанська', 88)
# ('Печерський, Голосіївський, Шевченківський', 'Жилянська', 41)
# ('Дніпровський', 'Комбінатна', 150)
# ('Дарницький', 'Ревуцького', 73)
# (None, 'Бородіна', 81)
# (None, 'Руставелі', 50)
# ('Дарницький', 'Драгоманова', 37)
# ("Солом'янський", 'Преображенська', 60)
# ('Святошинський', 'Депутатська', 30)
# ('Шевченківський', 'Багговутівська', 63)
# (None, '*** not found', 213)
# (None, 'Сікорського', 0)
# (None, 'Драгомирова', 0)
# ('Шевченківський', 'Коперніка', 87)
# ('Голосіївський', 'Васильківська', 68)
# ('Шевченківський', 'Глибочицька', 103)
# (None, 'Чавдар', 0)
# ('Печерський', 'Шовковична', 91)
# ('Оболонський', 'Дніпровська', 64)
# ('Голосіївський, Печерський', 'Антоновича', 61)
# (None, None, 94)
# ('Дарницький', 'Славгородська', 111)
# (None, 'Драгомирова', 46)
# ('Дарницький', 'Срібнокільська', 40)
# (None, 'Харченка', 70)
# (None, 'Окіпної', 84)
# ('Печерський', 'Саперне Поле', 53)
# (None, 'Олени Теліги', 80)
# (None, 'Кондратюка', 70)
# ('Печерський', 'Мечнікова', 137)
# ('Оболонський', 'Героїв Сталінграда', 51)
# ('Печерський', 'Рибальська', 52)
# ("Солом'янський", 'Березова', 248)
# ('Печерський', 'Саперне Поле', 52)
# ('Голосіївський, Печерський', 'Антоновича', 74)
# (None, 'Маккейна', 108)
# ('Печерський', 'Лейпцизька', 0)
# ('Дарницький', 'Драгоманова', 0)
# (None, 'Коновальця', 55)
# (None, 'Василя Стуса', 67)
# (None, 'Тютюнника', 70)
# ('Шевченківський', 'Січових Стрільців', 88)
# ('Дніпровський', 'Райдужна', 24)
# (None, 'Закревського', 0)
# ('Шевченківський', 'Тургенєвська', 0)
# ('Голосіївський', 'Васильківська', 46)
# (None, "Зої Космодем'янської", 250)
# (None, 'Радченка', 37)
# (None, 'Сверстюка', 51)
# ('Деснянський', 'Милославська', 61)
# ('Голосіївський', 'Метрологічна', 110)
# ('Голосіївський', 'Деміївська', 64)
# ('Голосіївський', 'Деміївська', 64)
# ('Святошинський', 'Перемоги', 0)
# ('Шевченківський', 'Перемоги', 0)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 0)
# ('Подільський, Оболонський', 'Вишгородська', 110)
# (None, 'Маккейна', 51)
# (None, None, 70)
# ('Святошинський', 'Перемоги', 45)
# ('Шевченківський', 'Перемоги', 45)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 45)
# ('Оболонський', 'Балтійський', 0)
# ('Печерський', 'Звіринецька', 70)
# ('Дарницький', 'Ревуцького', 0)
# ('Подільський', 'Правди', 80)
# ('Деснянський', 'Милославська', 40)
# (None, 'Вербицького', 54)
# ("Солом'янський", 'Новгородська', 98)
# (None, 'Бажана', 185)
# ('Подільський', 'Канівська', 0)
# ('Святошинський', 'Максимовича', 73)
# (None, 'Донця', 110)
# (None, 'Драгомирова', 40)
# ('Подільський', 'Тираспольська', 165)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 74)
# ('Подільський', 'Тираспольська', 57)
# ('Дарницький', 'Зарічна', 70)
# (None, 'Гонгадзе', 0)
# (None, 'Українки', 78)
# ('Подільський', 'Світлицького', 0)
# (None, 'Воробйова', 92)
# ('Дніпровський', 'Каховська', 54)
# ('Шевченківський', 'Глибочицька', 85)
# (None, 'Білокур', 350)
# ('Оболонський', 'Балтійський', 0)
# ('Голосіївський, Печерський', 'Антоновича', 170)
# (None, 'Кондратюка', 48)
# (None, 'Гончара', 55)
# ('Дарницький', 'Ревуцького', 230)
# (None, '*** not found', 0)
# ('Дарницький', 'Драгоманова', 0)
# (None, 'Сім’ї Кульженків', 0)
# (None, 'Панельна', 0)
# (None, 'Вільямса', 29)
# ('Голосіївський', 'Голосіївська', 67)
# ('Голосіївський', 'Голосіївська', 67)
# ('Оболонський', 'Оболонський', 72)
# ("Солом'янський", 'Миколи Голего', 55)
# ('Оболонський', 'Дніпровська', 0)
# (None, 'Малиновського', 0)
# ('Шевченківський', 'Назарівська', 62)
# ('Шевченківський', 'Гоголівська', 130)
# ('Шевченківський', 'Дорогожицька', 67)
# ('Оболонський', 'Петропавлівська', 42)
# ('Подільський', 'Петропавлівська', 42)
# (None, 'Грушевського', 74)
# (None, 'Іллєнка', 88)
# (None, 'Липківського', 49)
# ("Солом'янський", 'Ушинського', 42)
# ("Солом'янський", 'Ушинського', 42)
# ('Дарницький', 'Польова', 49)
# ('Деснянський', 'Польова', 49)
# ("Солом'янський", 'Польова', 49)
# ('Печерський', 'Саперне Поле', 55)
# (None, 'Панельна', 42)
# (None, 'Коновальця', 142)
# (None, 'Хмельницького', 50)
# (None, 'Маккейна', 32)
# ('Голосіївський, Печерський', 'Антоновича', 44)
# ('Дарницький', 'Толстого', 52)
# ('Печерський', 'Дружби Народів', 156)
# ('Оболонський', 'Оболонський', 123)
# ('Шевченківський', 'Багговутівська', 165)
# (None, 'Антонова', 66)
# ('Голосіївський, Шевченківський', 'Володимирська', 0)
# (None, 'Українки', 41)
# (None, 'Сім’ї Кульженків', 42)
# (None, 'Коновальця', 61)
# (None, 'Мирного', 80)
# ('Печерський', 'Московська', 119)
# ("Солом'янський", 'Московська', 119)
# ('Святошинський', 'Жмеринська', 53)
# (None, 'Бойчука', 63)
# (None, 'Липківського', 43)
# ('Печерський', 'Лабораторний', 86)
# ('Печерський', 'Інститутська', 120)
# (None, 'Українки', 108)
# ('Печерський, Шевченківський', 'Хрещатик', 94)
# ('Оболонський', 'Дніпровська', 115)
# ('Дарницький', 'Осокорська', 0)
# ('Печерський', 'Саперне Поле', 55)
# (None, 'Комарова', 62)
# (None, 'Драгомирова', 53)
# ('Дарницький', 'Срібнокільська', 0)
# ("Солом'янський", 'Чоколівський', 122)
# ('Печерський', 'Звіринецька', 90)
# ('Подільський, Оболонський', 'Вишгородська', 55)
# (None, 'Драгомирова', 40)
# ('Оболонський', 'Героїв Сталінграда', 46)
# ('Деснянський', 'Будівельників', 340)
# ('Дніпровський', 'Будівельників', 340)
# ('Дніпровський', 'Будівельників', 340)
# ('Святошинський', 'Будівельників', 340)
# (None, 'Іллєнка', 41)
# ('Дарницький', 'Урлівська', 47)
# ('Дарницький', 'Сормовська', 55)
# ('Подільський', 'Правди', 79)
# ('Святошинський', 'Верховинна', 65)
# (None, 'Вербицького', 32)
# (None, '*** not found', 63)
# ('Голосіївський, Шевченківський, Печерський', 'Велика Васильківська', 50)
# (None, 'Бойчука', 36)
# (None, 'Лобановського', 35)
# (None, 'Миколи Шепелєва', 52)
# ('Печерський', 'Кропивницького', 50)
# ('Дарницький', 'Трускавецька', 165)
# ('Голосіївський', 'Голосіївська', 71)
# ('Голосіївський', 'Голосіївська', 71)
# (None, 'Маланюка', 110)
# (None, 'Драгомирова', 102)
# ('Святошинський', 'Юнацька', 80)
# ("Солом'янський", 'Юнацька', 80)
# ('Святошинський', 'Максимовича', 60)
# (None, 'Комарова', 70)
# ('Шевченківський', 'Багговутівська', 80)
# (None, None, 84)
# ('Голосіївський', 'Костанайська', 72)
# ('Дарницький', 'Срібнокільська', 96)
# (None, 'Курчатова', 32)
# ('Печерський', 'Гусовського', 113)
# (None, 'Українки', 119)
# ('Дарницький', 'Драгоманова', 61)
# ('Оболонський', 'Дніпровська', 75)
# (None, 'Заболотного', 0)
# (None, 'Заболотного', 82)
# ('Святошинський', 'Перемоги', 98)
# ('Шевченківський', 'Перемоги', 98)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 98)
# (None, 'Сверстюка', 32)
# (None, 'Липківського', 37)
# (None, 'Маккейна', 96)
# ('Оболонський', 'Дніпровська', 74)
# ('Деснянський', 'Волгоградська', 54)
# ("Солом'янський", 'Волгоградська', 54)
# ("Солом'янський", 'Новопольова', 88)
# ('Дарницький', 'Драгоманова', 0)
# (None, 'Лебедєва', 65)
# (None, '*** not found', 50)
# (None, 'Драгомирова', 100)
# ('Печерський', 'Лейпцизька', 125)
# ('Шевченківський', 'Глибочицька', 55)
# ('Шевченківський', 'Салютна', 55)
# ('Голосіївський', 'Метрологічна', 49)
# ('Подільський', 'Північно-Сирецька', 0)
# ('Подільський', 'Правди', 55)
# (None, 'Вернадського', 0)
# (None, 'Пчілки', 130)
# ('Печерський', 'Лейпцизька', 40)
# ('Печерський, Шевченківський', 'Басейна', 56)
# (None, 'Шаповала', 75)
# ('Оболонський', 'Бережанська', 98)
# (None, 'Бойчука', 0)
# ('Святошинський', 'Перемоги', 51)
# ('Шевченківський', 'Перемоги', 51)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 51)
# (None, 'Івана Федорова', 32)
# ('Голосіївський, Печерський', 'Антоновича', 308)
# (None, 'Вільямса', 30)
# (None, 'Бойчука', 90)
# ('Святошинський', 'Перемоги', 61)
# ('Шевченківський', 'Перемоги', 61)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 61)
# ('Голосіївський, Печерський', 'Ковпака', 105)
# ('Дніпровський', 'Русанівський', 32)
# (None, 'Українки', 27)
# ('Дніпровський', 'Празька', 37)
# (None, 'Гончара', 76)
# (None, 'Маккейна', 75)
# ('Оболонський', 'Балтійський', 65)
# ('Шевченківський', 'Білоруська', 114)
# ('Дарницький', 'Драгоманова', 152)
# (None, 'Липківського', 115)
# ('Печерський', 'Новогоспітальна', 89)
# (None, 'Радченка', 70)
# (None, 'Богомольця', 0)
# (None, 'Донця', 0)
# ('Оболонський', 'Оболонський', 85)
# ('Подільський', 'Щекавицька', 83)
# ('Подільський', 'Щекавицька', 83)
# ('Деснянський', 'Пожарського', 119)
# ('Дніпровський', 'Пожарського', 119)
# ('Подільський', 'Полкова', 100)
# (None, 'Донця', 42)
# (None, 'Палладіна', 44)
# (None, 'Бойчука', 262)
# (None, 'Липківського', 125)
# ('Шевченківський', 'Павлівська', 35)
# (None, 'Івашкевича', 51)
# ("Солом'янський", 'Іскрівська', 66)
# ('Святошинський', 'Максимовича', 68)
# (None, '*** not found', 70)
# (None, 'Драгомирова', 113)
# ('Голосіївський', 'Теремківська', 0)
# ('Дарницький', 'Осокорська', 108)
# ('Подільський', 'Дмитрівська', 46)
# ('Шевченківський', 'Дмитрівська', 46)
# (None, 'Кондратюка', 60)
# ('Дніпровський', 'Регенераторна', 125)
# (None, None, 58)
# ('Шевченківський', 'Глибочицька', 0)
# ('Оболонський', 'Героїв Сталінграда', 120)
# ("Солом'янський, Шевченківський ", 'Борщагівська', 68)
# ('Дарницький', 'Ревуцького', 42)
# ('Святошинський', 'Юнацька', 69)
# ("Солом'янський", 'Юнацька', 69)
# (None, 'Заболотного', 86)
# ('Оболонський', 'Автозаводська', 32)
# (None, 'Заболотного', 0)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 52)
# ('Дарницький', 'Зарічна', 92)
# (None, '*** not found', 60)
# (None, 'Невська', 0)
# ('Оболонський', 'Героїв Сталінграда', 189)
# ('Дарницький', 'Вишняківська', 59)
# (None, 'Драгомирова', 69)
# (None, 'Драгомирова', 48)
# (None, 'Гавела', 62)
# ('Дарницький', 'Здолбунівська', 87)
# (None, 'Драгомирова', 83)
# ('Печерський', 'Мечнікова', 65)
# (None, '*** not found', 37)
# ('Святошинський', 'Максимовича', 56)
# ('Шевченківський', 'Багговутівська', 64)
# ('Шевченківський', 'Шолуденка', 78)
# ('Подільський', 'Щекавицька', 64)
# ('Подільський', 'Щекавицька', 64)
# (None, 'Коласа', 37)
# (None, '*** not found', 117)
# (None, '*** not found', 45)
# ('Святошинський', 'Перемоги', 42)
# ('Шевченківський', 'Перемоги', 42)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 42)
# (None, '*** not found', 115)
# (None, 'Наумова', 0)
# ('Святошинський', 'Перемоги', 76)
# ('Шевченківський', 'Перемоги', 76)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 76)
# ('Голосіївський, Шевченківський, Печерський', 'Велика Васильківська', 115)
# (None, 'Червоноткацька', 0)
# ('Подільський, Оболонський', 'Вишгородська', 0)
# (None, 'Омеляновича-Павленка', 73)
# (None, None, 0)
# (None, 'Ованеса Туманяна', 100)
# ('Оболонський', 'Петропавлівська', 58)
# ('Подільський', 'Петропавлівська', 58)
# ('Оболонський', 'Дніпровська', 79)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 0)
# (None, 'Івана Мазепи', 0)
# ('Оболонський', 'Дніпровська', 87)
# ('Голосіївський, Печерський', 'Ділова', 40)
# (None, 'Новодарницька', 51)
# ('Дарницький', 'Ревуцького', 48)
# (None, 'Липківського', 85)
# (None, 'Бендукідзе', 76)
# ('Подільський', 'Введенська', 56)
# ('Печерський', 'Виноградний', 38)
# ("Голосіївський,Солом'янський", 'Кайсарова', 70)
# (None, 'Ахматової', 103)
# (None, 'Радченка', 0)
# ('Оболонський', 'Дніпровська', 69)
# ('Голосіївський, Печерський', 'Ділова', 0)
# ('Дарницький', 'Бориспільська', 50)
# ('Печерський', 'Болсуновська', 64)
# (None, 'Українки', 96)
# (None, 'Антонова', 46)
# (None, 'Омеляновича-Павленка', 44)
# (None, None, 100)
# (None, 'Ованеса Туманяна', 240)
# ('Оболонський', 'Петропавлівська', 0)
# ('Подільський', 'Петропавлівська', 0)
# ('Оболонський', 'Дніпровська', 75)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 78)
# (None, 'Івана Мазепи', 126)
# ('Оболонський', 'Дніпровська', 93)
# ('Голосіївський, Печерський', 'Ділова', 63)
# (None, 'Новодарницька', 44)
# ('Дарницький', 'Ревуцького', 0)
# (None, 'Липківського', 52)
# (None, 'Бендукідзе', 99)
# ('Подільський', 'Введенська', 96)
# ('Печерський', 'Виноградний', 65)
# ("Голосіївський,Солом'янський", 'Кайсарова', 50)
# (None, 'Ахматової', 76)
# (None, 'Радченка', 0)
# ('Оболонський', 'Дніпровська', 99)
# ('Голосіївський, Печерський', 'Ділова', 0)
# ('Дарницький', 'Бориспільська', 59)
# ('Печерський', 'Болсуновська', 73)
# (None, 'Українки', 62)
# (None, 'Антонова', 76)
# ('Голосіївський', 'Науки', 76)
# ('Голосіївський', 'Метрологічна', 210)
# ('Печерський', 'Дружби Народів', 33)
# (None, '*** not found', 0)
# (None, 'Драгомирова', 62)
# (None, 'Данченка', 0)
# ('Голосіївський', 'Кримська', 110)
# ("Солом'янський", 'Новопольова', 51)
# (None, 'Туполєва', 44)
# (None, '*** not found', 91)
# ('Оболонський', 'Дніпровська', 28)
# ('Святошинський', 'Перемоги', 56)
# ('Шевченківський', 'Перемоги', 56)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 56)
# (None, 'Івана Федорова', 0)
# ('Деснянський, Дніпровський', 'Братиславська', 100)
# (None, '*** not found', 82)
# (None, 'Червоноткацька', 122)
# (None, 'Златоустівська', 45)
# (None, 'Бойченка', 75)
# ('Дарницький', 'Трускавецька', 34)
# ('Дніпровський', 'Каховська', 46)
# (None, 'Лобановського', 100)
# (None, '*** not found', 99)
# (None, 'Курчатова', 75)
# ('Голосіївський', 'Голосіївська', 62)
# ('Голосіївський', 'Голосіївська', 62)
# ('Подільський', 'Тираспольська', 76)
# ('Печерський', 'Лаврська', 210)
# ('Подільський', 'Правди', 33)
# (None, 'Миколайчука', 0)
# (None, 'Порика', 62)
# (None, 'Червоноткацька', 0)
# (None, 'Маккейна', 110)
# ('Оболонський', 'Йорданська', 51)
# (None, 'Тютюнника', 44)
# ('Дніпровський', 'Регенераторна', 91)
# ('Дарницький', 'Зарічна', 28)
# (None, 'Заболотного', 56)
# ('Дніпровський, Деснянський', 'Курнатовського', 0)
# ('Печерський', 'Інститутська', 100)
# (None, 'Маланюка', 82)
# (None, 'Гречка', 122)
# (None, 'Липківського', 45)
# (None, 'Маккейна', 75)
# (None, 'Григоренка', 34)
# (None, 'Коновальця', 46)
# (None, 'Закревського', 100)
# (None, '*** not found', 99)
# ('Печерський', 'Старонаводницька', 75)
# (None, 'Маланюка', 62)
# ('Печерський', 'Заньковецької', 72)
# ('Шевченківський', 'Кудрявська', 0)
# (None, None, 159)
# (None, 'Українки', 76)
# (None, None, 0)
# ('Деснянський', 'Милославська', 44)
# (None, 'Донця', 95)
# (None, 'Верховинця', 240)
# ('Оболонський', 'Героїв Дніпра', 36)
# ('Дніпровський', 'Каховська', 50)
# ('Дніпровський', 'Каховська', 71)
# ('Дарницький', 'Вишняківська', 0)
# (None, 'Липська', 0)
# (None, 'Сверстюка', 123)
# (None, 'Драгомирова', 74)
# ('Дарницький', 'Причальна', 81)
# ('Печерський', 'Болсуновська', 43)
# ("Шевченківський, Солом'янський", 'Повітрофлотський', 84)
# ('Дарницький', 'Драгоманова', 46)
# (None, 'Григоренка', 55)
# ('Оболонський', 'Дніпровська', 136)
# (None, 'Жабаєва', 0)
# (None, 'Філатова', 136)
# ('Подільський', 'Правди', 41)
# ('Шевченківський', 'Малопідвальна', 71)
# (None, 'Бойчука', 57)
# ('Дарницький', 'Зарічна', 149)
# ('Печерський', 'Предславинська', 50)
# (None, 'Івана Мазепи', 75)
# (None, 'Радченка', 92)
# ('Печерський', 'Лабораторний', 60)
# (None, 'Конєва', 0)
# (None, 'Шаповала', 0)
# ('Оболонський', 'Дніпровська', 55)
# ('Дарницький', 'Клеманська', 83)
# (None, 'Григоренка', 55)
# (None, 'Туполєва', 36)
# (None, 'Хмельницького', 65)
# ('Печерський', 'Саперне Поле', 112)
# ('Оболонський', 'Героїв Сталінграда', 50)
# ('Оболонський', 'Дніпровська', 68)
# ('Голосіївський', 'Тарасівська', 85)
# ('Дніпровський', 'Краківська', 51)
# ('Святошинський', 'Юнацька', 46)
# ("Солом'янський", 'Юнацька', 46)
# ('Дарницький', 'Клеманська', 207)
# ('Оболонський', 'Героїв Сталінграда', 130)
# (None, 'Драгомирова', 81)
# (None, '*** not found', 41)
# ('Дарницький', 'Драгоманова', 50)
# (None, 'Українки', 54)
# (None, 'Тимошенка', 83)
# ('Деснянський', 'Маяковського', 81)
# ('Подільський', 'Дмитрівська', 44)
# ('Шевченківський', 'Дмитрівська', 44)
# (None, 'Курбаса', 90)
# (None, 'Комарова', 79)
# ('Дарницький', 'Драгоманова', 43)
# (None, 'Драгомирова', 51)
# (None, 'Моторний', 0)
# ('Деснянський', 'Милославська', 0)
# (None, 'Бойчука', 110)
# (None, 'Закревського', 106)
# (None, 'Івана Федорова', 72)
# (None, 'Філатова', 122)
# ('Святошинський', 'Перемоги', 67)
# ('Шевченківський', 'Перемоги', 67)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 67)
# ('Деснянський, Дніпровський', 'Миропільська', 273)
# (None, 'Григоренка', 83)
# ('Святошинський', 'Юнацька', 45)
# ("Солом'янський", 'Юнацька', 45)
# ('Подільський, Оболонський', 'Вишгородська', 0)
# ('Святошинський', 'Жолудєва', 0)
# ('Шевченківський', 'Павлівська', 49)
# ('Голосіївський', 'Голосіївський', 0)
# ('Голосіївський', 'Голосіївський', 0)
# ('Дарницький', 'Осокорська', 183)
# ('Подільський, Оболонський', 'Вишгородська', 0)
# (None, 'Драгомирова', 76)
# (None, 'Тютюнника', 160)
# (None, 'Маккейна', 0)
# (None, 'Івана Мазепи', 0)
# ('Оболонський', 'Героїв Сталінграда', 73)
# (None, 'Липківського', 0)
# (None, '*** not found', 44)
# (None, 'Коновальця', 75)
# ('Святошинський', 'Максимовича', 60)
# ('Дарницький', 'Зарічна', 34)
# ('Голосіївський', 'Голосіївська', 65)
# ('Голосіївський', 'Голосіївська', 65)
# ('Голосіївський', 'Ясинуватський', 190)
# (None, '*** not found', 240)
# (None, 'Колоса', 85)
# ('Подільський', 'Правди', 48)
# ('Голосіївський, Шевченківський, Печерський', 'Велика Васильківська', 75)
# ('Голосіївський', 'Голосіївський', 60)
# ('Голосіївський', 'Голосіївський', 60)
# (None, '*** not found', 0)
# (None, 'Бойчука', 0)
# ('Дніпровський', 'Центральна', 50)
# ('Оболонський', 'Центральна', 50)
# ('Шевченківський', 'Центральна', 50)
# ('Голосіївський', 'Ясинуватський', 71)
# ('Дніпровський', 'Райдужна', 0)
# ('Голосіївський', 'Ломоносова', 68)
# (None, None, 44)
# (None, '*** not found', 48)
# ('Печерський', 'Гусовського', 46)
# (None, 'Окіпної', 0)
# ('Шевченківський', 'Багговутівська', 0)
# ('Печерський', 'Дружби Народів', 63)
# (None, 'Маккейна', 71)
# (None, 'Маланюка', 35)
# (None, 'Михайла Котельникова', 48)
# ("Солом'янський", 'Героїв Севастополя', 56)
# (None, 'Маланюка', 206)
# ('Печерський', 'Саперне Поле', 172)
# ('Оболонський', 'Балтійський', 45)
# ('Шевченківський', 'Кудрявська', 85)
# ('Святошинський', 'Перемоги', 49)
# ('Шевченківський', 'Перемоги', 49)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 49)
# ('Печерський', 'Німанська', 193)
# ('Дніпровський', 'Каховська', 0)
# ('Шевченківський', 'Малопідвальна', 43)
# (None, 'Невська', 350)
# (None, 'Златоустівська', 127)
# (None, None, 0)
# ('Святошинський', 'Берковецька', 180)
# (None, 'Бажана', 0)
# ('Голосіївський, Печерський', 'Антоновича', 0)
# (None, '*** not found', 60)
# (None, 'Гречка', 60)
# ('Дніпровський', 'Микільсько-Слобідська', 174)
# ('Подільський', 'Правди', 73)
# (None, 'Тимошенка', 93)
# (None, 'Павла Тичини', 0)
# ('Святошинський', 'Олевська', 140)
# ("Солом'янський", 'Освіти', 50)
# (None, 'Іллєнка', 88)
# ('Оболонський', 'Дніпровська', 0)
# (None, 'Івана Мазепи', 43)
# (None, 'Українки', 72)
# (None, 'Данченка', 247)
# (None, 'Драгомирова', 250)
# (None, 'Тбіліський', 67)
# ('Дніпровський', 'Каховська', 81)
# ("Солом'янський", 'Ушинського', 33)
# ("Солом'янський", 'Ушинського', 33)
# ('Дарницький', 'Урлівська', 0)
# ('Подільський', 'Світлицького', 93)
# ('Оболонський', 'Дніпровська', 109)
# (None, 'Липківського', 0)
# ('Дніпровський', 'Микільсько-Слобідська', 55)
# (None, 'Лобановського', 88)
# ('Оболонський', 'Героїв Сталінграда', 0)
# ('Оболонський', 'Дніпровська', 150)
# ('Дарницький', 'Драгоманова', 87)
# (None, 'Ахматової', 275)
# ('Печерський', 'Саперне Поле', 80)
# (None, 'Данченка', 54)
# ('Голосіївський', 'Голосіївський', 43)
# ('Голосіївський', 'Голосіївський', 43)
# (None, '*** not found', 94)
# ('Шевченківський', 'Глибочицька', 42)
# ('Шевченківський', 'Багговутівська', 0)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 116)
# (None, 'Моторний', 76)
# ('Оболонський', 'Йорданська', 59)
# ('Печерський', 'Саперне Поле', 200)
# (None, 'Вернадського', 70)
# (None, 'Курбаса', 0)
# ('Шевченківський', 'Багговутівська', 150)
# ('Подільський', 'Набережно-Рибальська', 162)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 45)
# (None, 'Малиновського', 62)
# ("Солом'янський", 'Протасів Яр', 75)
# ('Печерський', 'Німанська', 0)
# (None, 'Підвисоцького', 70)
# ('Святошинський', 'Зодчих', 95)
# (None, 'Рокосовського', 555)
# ('Печерський', 'Шовковична', 0)
# (None, 'Крушельницької', 93)
# ("Солом'янський", 'Новопольова', 55)
# ('Дніпровський', 'Визволителів', 102)
# ('Дніпровський', 'Сонячна', 94)
# ('Шевченківський', 'Сонячна', 94)
# (None, 'Сікорського', 41)
# (None, 'Радченка', 0)
# ('Шевченківський', 'Бульварно-Кудрявська', 0)
# ("Голосіївський,Солом'янський", 'Кайсарова', 0)
# ('Оболонський', 'Дніпровська', 67)
# ('Дніпровський', 'Перова', 0)
# (None, 'Глушкова', 31)
# (None, 'Рокосовського', 87)
# ('Голосіївський', 'Саперно-Слобідська', 82)
# (None, 'Миколи Кибальчича', 50)
# (None, 'Миколи Ушакова', 40)
# ('Голосіївський, Печерський', 'Антоновича', 70)
# ("Солом'янський", 'Богданівська', 75)
# (None, None, 96)
# (None, 'Сверстюка', 56)
# ('Дарницький', 'Ревуцького', 43)
# (None, 'Ованеса Туманяна', 119)
# ('Печерський', 'Саперне Поле', 43)
# (None, 'Григоренка', 22)
# (None, 'Гречка', 105)
# ('Оболонський', 'Богатирська', 44)
# ('Шевченківський', 'Білоруська', 69)
# ('Дніпровський', 'Регенераторна', 45)
# ('Дарницький', 'Вишняківська', 95)
# (None, 'Гонгадзе', 28)
# ('Подільський', 'Правди', 40)
# ('Святошинський', 'Кольцова', 161)
# ('Дніпровський', 'Воскресенська', 100)
# (None, 'Руставелі', 65)
# ('Голосіївський', 'Голосіївський', 213)
# ('Голосіївський', 'Голосіївський', 213)
# ('Дніпровський', 'Комбінатна', 62)
# ('Шевченківський', 'Салютна', 63)
# (None, 'Маланюка', 90)
# (None, 'Ромоданова', 39)
# ('Печерський', 'Саперне Поле', 73)
# (None, 'Сім’ї Кульженків', 34)
# ('Голосіївський, Печерський', 'Лабораторна', 50)
# ('Дарницький', 'Драгоманова', 39)
# (None, None, 55)
# ('Шевченківський', 'Кудрявська', 58)
# ('Дніпровський', 'Краківська', 52)
# ('Святошинський', 'Кольцова', 92)
# ('Голосіївський, Печерський', 'Антоновича', 68)
# (None, 'Лариси Руденко', 0)
# (None, 'Івана Пулюя', 65)
# (None, 'Українки', 145)
# (None, 'Тютюнника', 58)
# (None, 'Юрія Смолича', 76)
# ('Оболонський', 'Оболонський', 46)
# (None, 'Курбаса', 88)
# (None, 'Верховинця', 0)
# ('Дарницький', 'Зарічна', 0)
# ('Оболонський', 'Дніпровська', 58)
# ('Голосіївський', 'Коломийський', 52)
# ('Подільський', 'Правди', 70)
# ('Дніпровський', 'Каховська', 65)
# (None, 'Бойчука', 47)
# ('Подільський', 'Правди', 79)
# (None, 'Маккейна', 34)
# ('Святошинський', 'Перемоги', 98)
# ('Шевченківський', 'Перемоги', 98)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 98)
# (None, 'Грушевського', 50)
# ('Дарницький', 'Срібнокільська', 70)
# ('Святошинський', 'Перемоги', 45)
# ('Шевченківський', 'Перемоги', 45)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 45)
# ('Дарницький', 'Урлівська', 150)
# (None, 'Заболотного', 66)
# ('Святошинський', 'Максимовича', 65)
# (None, 'Бажана', 130)
# (None, 'Сікорського', 70)
# (None, 'Курбаса', 60)
# ('Оболонський', 'Дніпровська', 78)
# (None, 'Драгомирова', 53)
# (None, None, 65)
# (None, 'Антонова', 0)
# (None, 'Бучми', 69)
# ('Деснянський', 'Кубанської України', 61)
# ('Оболонський', 'Дніпровська', 81)
# (None, 'Панельна', 57)
# (None, 'Коновальця', 48)
# ('Оболонський', 'Богатирська', 47)
# ('Оболонський', 'Оболонський', 93)
# (None, 'Українки', 49)
# (None, 'Бориса Гмирі', 0)
# ('Подільський', 'Правди', 72)
# ('Дніпровський', 'Центральна', 65)
# ('Оболонський', 'Центральна', 65)
# ('Шевченківський', 'Центральна', 65)
# ("Солом'янський", 'Преображенська', 49)
# (None, 'Коновальця', 31)
# (None, 'Українки', 41)
# (None, '*** not found', 53)
# ('Голосіївський, Шевченківський, Печерський', 'Велика Васильківська', 77)
# (None, 'Липківського', 100)
# (None, 'Бойчука', 55)
# ('Голосіївський', 'Васильківська', 58)
# (None, 'Данькевича', 52)
# ('Оболонський', 'Богатирська', 312)
# (None, 'Українки', 87)
# (None, 'Гречка', 145)
# ('Печерський', 'Редутна', 50)
# (None, 'Бориса Гмирі', 125)
# (None, 'Драгомирова', 43)
# (None, 'Туполєва', 130)
# (None, 'Кондратюка', 81)
# ('Оболонський', 'Мінський', 208)
# ('Подільський', 'Мінський', 208)
# ('Дарницький', 'Княжий Затон', 306)
# ('Шевченківський', 'Герцена', 54)
# ('Шевченківський', 'Герцена', 54)
# ('Шевченківський', 'Герцена', 54)
# ('Оболонський', 'Балтійський', 105)
# (None, 'Ернста', 69)
# (None, 'Шаповала', 66)
# (None, 'Городецького', 67)
# (None, "Сім'ї Сосніних", 46)
# (None, 'Івана Мазепи', 104)
# (None, 'Червоноткацька', 55)
# (None, '*** not found', 92)
# ('Голосіївський', 'Голосіївська', 86)
# ('Голосіївський', 'Голосіївська', 86)
# (None, '*** not found', 87)
# (None, 'Миколи Гулака', 0)
# (None, 'Івана Федорова', 0)
# ('Печерський', 'Саперне Поле', 0)
# (None, 'Миколи Хвильового', 0)
# ('Шевченківський', 'Паторжинського', 0)
# (None, 'Наумовича', 51)
# (None, 'Калнишевського', 250)
# ('Оболонський', 'Дніпровська', 25)
# ('Подільський', 'Електриків', 42)
# ('Подільський', 'Електриків', 42)
# ("Солом'янський", "Солом'янська", 46)
# ("Солом'янський", "Солом'янська", 46)
# ('Дарницький', 'Шевченка', 127)
# ('Дарницький', 'Шевченка', 127)
# ('Деснянський', 'Шевченка', 127)
# ("Солом'янський", 'Шевченка', 127)
# ("Солом'янський", 'Шевченка', 127)
# ('Дарницький', 'Озерна', 46)
# ('Оболонський', 'Озерна', 46)
# ('Святошинський (СТ "Нивки")', 'Озерна', 46)
# ("Солом'янський", 'Озерна', 46)
# (None, 'Григоренка', 66)
# (None, 'Антонова', 0)
# ('Голосіївський', 'Голосіївський', 70)
# ('Голосіївський', 'Голосіївський', 70)
# (None, 'Комарова', 81)
# ("Солом'янський, Шевченківський ", 'Борщагівська', 0)
# ('Дарницький', 'Шевченка', 0)
# ('Дарницький', 'Шевченка', 0)
# ('Деснянський', 'Шевченка', 0)
# ("Солом'янський", 'Шевченка', 0)
# ("Солом'янський", 'Шевченка', 0)
# ('Святошинський', 'Максимовича', 85)
# ("Солом'янський", 'Ковальський', 79)
# (None, 'Малевича', 83)
# ('Деснянський', 'Мічуріна', 38)
# ('Оболонський', 'Мічуріна', 38)
# ('Печерський', 'Мічуріна', 38)
# ('Печерський', 'Мічуріна', 38)
# ("Солом'янський", 'Мічуріна', 38)
# (None, '*** not found', 160)
# ('Оболонський', 'Балтійський', 37)
# ('Дніпровський', 'Азербайджанська', 0)
# ('Дарницький', 'Зарічна', 108)
# (None, 'Чавдар', 150)
# ('Подільський', 'Правди', 72)
# ('Дарницький', 'Урлівська', 0)
# ('Дарницький', 'Бориспільська', 41)
# (None, 'Поправки', 53)
# ('Дарницький', 'Бориспільська', 43)
# ('Дніпровський', 'Ентузіастів', 0)
# ('Дарницький', 'Малоземельна', 71)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 56)
# ('Оболонський', 'Героїв Сталінграда', 118)
# ('Святошинський', 'Зодчих', 80)
# (None, 'Калнишевського', 85)
# (None, 'Філатова', 104)
# ('Печерський', 'Старонаводницька', 0)
# (None, 'Заболотного', 0)
# ('Подільський', 'Правди', 31)
# (None, '*** not found', 90)
# ('Голосіївський, Печерський', 'Антоновича', 104)
# (None, 'Шаповала', 46)
# (None, 'Івана Федорова', 103)
# ('Шевченківський', 'Деревлянська', 38)
# (None, 'Вільямса', 111)
# ("Солом'янський", 'Васильченка', 90)
# ('Печерський', 'Предславинська', 0)
# ('Деснянський', 'Крайня', 79)
# ('Деснянський', 'Милославська', 74)
# ('Дніпровський', 'Воскресенська', 46)
# (None, 'Маланюка', 49)
# ('Оболонський', 'Дніпровська', 76)
# ('Шевченківський', 'Пушкінська', 103)
# ('Голосіївський', 'Набережно-Корчуватська', 0)
# ('Дарницький', 'Зарічна', 110)
# ('Шевченківський', 'Тургенєвська', 70)
# (None, 'Радченка', 0)
# ('Дарницький', 'Зарічна', 60)
# ('Голосіївський', 'Метрологічна', 93)
# ('Оболонський', 'Йорданська', 130)
# ('Святошинський', 'Кольцова', 25)
# ('Святошинський', 'Максимовича', 55)
# ('Голосіївський', 'Науки', 171)
# ('Голосіївський', 'Саперно-Слобідська', 43)
# ('Печерський', 'Шовковична', 48)
# ('Дарницький', 'Трускавецька', 87)
# (None, 'Гавела', 53)
# ("Шевченківський, Солом'янський", 'Повітрофлотський', 84)
# (None, 'Запорожця', 46)
# (None, 'Маккейна', 52)
# ('Святошинський', 'Перемоги', 91)
# ('Шевченківський', 'Перемоги', 91)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 91)
# (None, 'Щербаківського', 65)
# ('Дарницький', 'Зарічна', 82)
# ('Деснянський', 'Будищанська', 88)
# ('Печерський, Голосіївський, Шевченківський', 'Жилянська', 41)
# ('Дніпровський', 'Комбінатна', 150)
# ('Дарницький', 'Ревуцького', 73)
# (None, 'Бородіна', 81)
# (None, 'Руставелі', 50)
# ('Дарницький', 'Драгоманова', 37)
# ("Солом'янський", 'Преображенська', 60)
# ('Святошинський', 'Депутатська', 30)
# ('Шевченківський', 'Багговутівська', 63)
# (None, '*** not found', 213)
# (None, 'Сікорського', 0)
# (None, 'Драгомирова', 0)
# ('Шевченківський', 'Коперніка', 87)
# ('Голосіївський', 'Васильківська', 68)
# ('Шевченківський', 'Глибочицька', 103)
# (None, 'Чавдар', 0)
# ('Печерський', 'Шовковична', 91)
# ('Оболонський', 'Дніпровська', 64)
# ('Голосіївський, Печерський', 'Антоновича', 61)
# (None, None, 94)
# ('Дарницький', 'Славгородська', 111)
# (None, 'Драгомирова', 46)
# ('Дарницький', 'Срібнокільська', 40)
# (None, 'Харченка', 70)
# (None, 'Окіпної', 84)
# ('Печерський', 'Саперне Поле', 53)
# (None, 'Олени Теліги', 80)
# (None, 'Кондратюка', 70)
# ('Печерський', 'Мечнікова', 137)
# ('Оболонський', 'Героїв Сталінграда', 51)
# ('Печерський', 'Рибальська', 52)
# ("Солом'янський", 'Березова', 248)
# ('Печерський', 'Саперне Поле', 52)
# ('Голосіївський, Печерський', 'Антоновича', 74)
# (None, 'Маккейна', 108)
# ('Печерський', 'Лейпцизька', 0)
# ('Дарницький', 'Драгоманова', 0)
# (None, 'Коновальця', 55)
# (None, 'Василя Стуса', 67)
# (None, 'Тютюнника', 70)
# ('Шевченківський', 'Січових Стрільців', 88)
# ('Дніпровський', 'Райдужна', 24)
# (None, 'Закревського', 0)
# ('Шевченківський', 'Тургенєвська', 0)
# ('Голосіївський', 'Васильківська', 46)
# (None, "Зої Космодем'янської", 250)
# (None, 'Радченка', 37)
# (None, 'Сверстюка', 51)
# ('Деснянський', 'Милославська', 61)
# ('Голосіївський', 'Метрологічна', 110)
# ('Голосіївський', 'Деміївська', 64)
# ('Голосіївський', 'Деміївська', 64)
# ('Святошинський', 'Перемоги', 0)
# ('Шевченківський', 'Перемоги', 0)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 0)
# ('Подільський, Оболонський', 'Вишгородська', 110)
# (None, 'Маккейна', 51)
# (None, None, 70)
# ('Святошинський', 'Перемоги', 45)
# ('Шевченківський', 'Перемоги', 45)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 45)
# ('Оболонський', 'Балтійський', 0)
# ('Печерський', 'Звіринецька', 70)
# ('Дарницький', 'Ревуцького', 0)
# ('Подільський', 'Правди', 80)
# ('Деснянський', 'Милославська', 40)
# (None, 'Вербицького', 54)
# ("Солом'янський", 'Новгородська', 98)
# (None, 'Бажана', 185)
# ('Подільський', 'Канівська', 0)
# ('Святошинський', 'Максимовича', 73)
# (None, 'Донця', 110)
# (None, 'Драгомирова', 40)
# ('Подільський', 'Тираспольська', 165)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 74)
# ('Подільський', 'Тираспольська', 57)
# ('Дарницький', 'Зарічна', 70)
# (None, 'Гонгадзе', 0)
# (None, 'Українки', 78)
# ('Подільський', 'Світлицького', 0)
# (None, 'Воробйова', 92)
# ('Дніпровський', 'Каховська', 54)
# ('Шевченківський', 'Глибочицька', 85)
# (None, 'Білокур', 350)
# ('Оболонський', 'Балтійський', 0)
# ('Голосіївський, Печерський', 'Антоновича', 170)
# (None, 'Кондратюка', 48)
# (None, 'Гончара', 55)
# ('Дарницький', 'Ревуцького', 230)
# (None, '*** not found', 0)
# ('Дарницький', 'Драгоманова', 0)
# (None, 'Сім’ї Кульженків', 0)
# (None, 'Панельна', 0)
# (None, 'Вільямса', 29)
# ('Голосіївський', 'Голосіївська', 67)
# ('Голосіївський', 'Голосіївська', 67)
# ('Оболонський', 'Оболонський', 72)
# ("Солом'янський", 'Миколи Голего', 55)
# ('Оболонський', 'Дніпровська', 0)
# (None, 'Малиновського', 0)
# ('Шевченківський', 'Назарівська', 62)
# ('Шевченківський', 'Гоголівська', 130)
# ('Шевченківський', 'Дорогожицька', 67)
# ('Оболонський', 'Петропавлівська', 42)
# ('Подільський', 'Петропавлівська', 42)
# (None, 'Грушевського', 74)
# (None, 'Іллєнка', 88)
# (None, 'Липківського', 49)
# ("Солом'янський", 'Ушинського', 42)
# ("Солом'янський", 'Ушинського', 42)
# ('Дарницький', 'Польова', 49)
# ('Деснянський', 'Польова', 49)
# ("Солом'янський", 'Польова', 49)
# ('Печерський', 'Саперне Поле', 55)
# (None, 'Панельна', 42)
# (None, 'Коновальця', 142)
# (None, 'Хмельницького', 50)
# (None, 'Маккейна', 32)
# ('Голосіївський, Печерський', 'Антоновича', 44)
# ('Дарницький', 'Толстого', 52)
# ('Печерський', 'Дружби Народів', 156)
# ('Оболонський', 'Оболонський', 123)
# ('Шевченківський', 'Багговутівська', 165)
# (None, 'Антонова', 66)
# ('Голосіївський, Шевченківський', 'Володимирська', 0)
# (None, 'Українки', 41)
# (None, 'Сім’ї Кульженків', 42)
# (None, 'Коновальця', 61)
# (None, 'Мирного', 80)
# ('Печерський', 'Московська', 119)
# ("Солом'янський", 'Московська', 119)
# ('Святошинський', 'Жмеринська', 53)
# (None, 'Бойчука', 63)
# (None, 'Липківського', 43)
# ('Печерський', 'Лабораторний', 86)
# ('Печерський', 'Інститутська', 120)
# (None, 'Українки', 108)
# ('Печерський, Шевченківський', 'Хрещатик', 94)
# ('Оболонський', 'Дніпровська', 115)
# ('Дарницький', 'Осокорська', 0)
# ('Печерський', 'Саперне Поле', 55)
# (None, 'Комарова', 62)
# (None, 'Драгомирова', 53)
# ('Дарницький', 'Срібнокільська', 0)
# ("Солом'янський", 'Чоколівський', 122)
# ('Печерський', 'Звіринецька', 90)
# ('Подільський, Оболонський', 'Вишгородська', 55)
# (None, 'Драгомирова', 40)
# ('Оболонський', 'Героїв Сталінграда', 46)
# ('Деснянський', 'Будівельників', 340)
# ('Дніпровський', 'Будівельників', 340)
# ('Дніпровський', 'Будівельників', 340)
# ('Святошинський', 'Будівельників', 340)
# (None, 'Іллєнка', 41)
# ('Дарницький', 'Урлівська', 47)
# ('Дарницький', 'Сормовська', 55)
# ('Подільський', 'Правди', 79)
# ('Святошинський', 'Верховинна', 65)
# (None, 'Вербицького', 32)
# (None, '*** not found', 63)
# ('Голосіївський, Шевченківський, Печерський', 'Велика Васильківська', 50)
# (None, 'Бойчука', 36)
# (None, 'Лобановського', 35)
# (None, 'Миколи Шепелєва', 52)
# ('Печерський', 'Кропивницького', 50)
# ('Дарницький', 'Трускавецька', 165)
# ('Голосіївський', 'Голосіївська', 71)
# ('Голосіївський', 'Голосіївська', 71)
# (None, 'Маланюка', 110)
# (None, 'Драгомирова', 102)
# ('Святошинський', 'Юнацька', 80)
# ("Солом'янський", 'Юнацька', 80)
# ('Святошинський', 'Максимовича', 60)
# (None, 'Комарова', 70)
# ('Шевченківський', 'Багговутівська', 80)
# (None, None, 84)
# ('Голосіївський', 'Костанайська', 72)
# ('Дарницький', 'Срібнокільська', 96)
# (None, 'Курчатова', 32)
# ('Печерський', 'Гусовського', 113)
# (None, 'Українки', 119)
# ('Дарницький', 'Драгоманова', 61)
# ('Оболонський', 'Дніпровська', 75)
# (None, 'Заболотного', 0)
# (None, 'Заболотного', 82)
# ('Святошинський', 'Перемоги', 98)
# ('Шевченківський', 'Перемоги', 98)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 98)
# (None, 'Сверстюка', 32)
# (None, 'Липківського', 37)
# (None, 'Маккейна', 96)
# ('Оболонський', 'Дніпровська', 74)
# ('Деснянський', 'Волгоградська', 54)
# ("Солом'янський", 'Волгоградська', 54)
# ("Солом'янський", 'Новопольова', 88)
# ('Дарницький', 'Драгоманова', 0)
# (None, 'Лебедєва', 65)
# (None, '*** not found', 50)
# (None, 'Драгомирова', 100)
# ('Печерський', 'Лейпцизька', 125)
# ('Шевченківський', 'Глибочицька', 55)
# ('Шевченківський', 'Салютна', 55)
# ('Голосіївський', 'Метрологічна', 49)
# ('Подільський', 'Північно-Сирецька', 0)
# ('Подільський', 'Правди', 55)
# (None, 'Вернадського', 0)
# (None, 'Пчілки', 130)
# ('Печерський', 'Лейпцизька', 40)
# ('Печерський, Шевченківський', 'Басейна', 56)
# (None, 'Шаповала', 75)
# ('Оболонський', 'Бережанська', 98)
# (None, 'Бойчука', 0)
# ('Святошинський', 'Перемоги', 51)
# ('Шевченківський', 'Перемоги', 51)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 51)
# (None, 'Івана Федорова', 32)
# ('Голосіївський, Печерський', 'Антоновича', 308)
# (None, 'Вільямса', 30)
# (None, 'Бойчука', 90)
# ('Святошинський', 'Перемоги', 61)
# ('Шевченківський', 'Перемоги', 61)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 61)
# ('Голосіївський, Печерський', 'Ковпака', 105)
# ('Дніпровський', 'Русанівський', 32)
# (None, 'Українки', 27)
# ('Дніпровський', 'Празька', 37)
# (None, 'Гончара', 76)
# (None, 'Маккейна', 75)
# ('Оболонський', 'Балтійський', 65)
# ('Шевченківський', 'Білоруська', 114)
# ('Дарницький', 'Драгоманова', 152)
# (None, 'Липківського', 115)
# ('Печерський', 'Новогоспітальна', 89)
# (None, 'Радченка', 70)
# (None, 'Богомольця', 0)
# (None, 'Донця', 0)
# ('Оболонський', 'Оболонський', 85)
# ('Подільський', 'Щекавицька', 83)
# ('Подільський', 'Щекавицька', 83)
# ('Деснянський', 'Пожарського', 119)
# ('Дніпровський', 'Пожарського', 119)
# ('Подільський', 'Полкова', 100)
# (None, 'Донця', 42)
# (None, 'Палладіна', 44)
# (None, 'Бойчука', 262)
# (None, 'Липківського', 125)
# ('Шевченківський', 'Павлівська', 35)
# (None, 'Івашкевича', 51)
# ("Солом'янський", 'Іскрівська', 66)
# ('Святошинський', 'Максимовича', 68)
# (None, '*** not found', 70)
# (None, 'Драгомирова', 113)
# ('Голосіївський', 'Теремківська', 0)
# ('Дарницький', 'Осокорська', 108)
# ('Подільський', 'Дмитрівська', 46)
# ('Шевченківський', 'Дмитрівська', 46)
# (None, 'Кондратюка', 60)
# ('Дніпровський', 'Регенераторна', 125)
# (None, None, 58)
# ('Шевченківський', 'Глибочицька', 0)
# ('Оболонський', 'Героїв Сталінграда', 120)
# ("Солом'янський, Шевченківський ", 'Борщагівська', 68)
# ('Дарницький', 'Ревуцького', 42)
# ('Святошинський', 'Юнацька', 69)
# ("Солом'янський", 'Юнацька', 69)
# (None, 'Заболотного', 86)
# ('Оболонський', 'Автозаводська', 32)
# (None, 'Заболотного', 0)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 52)
# ('Дарницький', 'Зарічна', 92)
# (None, '*** not found', 60)
# (None, 'Невська', 0)
# ('Оболонський', 'Героїв Сталінграда', 189)
# ('Дарницький', 'Вишняківська', 59)
# (None, 'Драгомирова', 69)
# (None, 'Драгомирова', 48)
# (None, 'Гавела', 62)
# ('Дарницький', 'Здолбунівська', 87)
# (None, 'Драгомирова', 83)
# ('Печерський', 'Мечнікова', 65)
# (None, '*** not found', 37)
# ('Святошинський', 'Максимовича', 56)
# ('Шевченківський', 'Багговутівська', 64)
# ('Шевченківський', 'Шолуденка', 78)
# ('Подільський', 'Щекавицька', 64)
# ('Подільський', 'Щекавицька', 64)
# (None, 'Коласа', 37)
# (None, '*** not found', 117)
# (None, '*** not found', 45)
# ('Святошинський', 'Перемоги', 42)
# ('Шевченківський', 'Перемоги', 42)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 42)
# (None, '*** not found', 115)
# (None, 'Наумова', 0)
# ('Святошинський', 'Перемоги', 76)
# ('Шевченківський', 'Перемоги', 76)
# ("Шевченківський, Святошинський, Солом'янський", 'Перемоги', 76)
# ('Голосіївський, Шевченківський, Печерський', 'Велика Васильківська', 115)
# (None, 'Червоноткацька', 0)
# ('Подільський, Оболонський', 'Вишгородська', 0)

# %% [markdown]
# #### для аналізу скористатися бібліотекою NumPy

# %%
import numpy as np

# %%
# створити np-масив з списку `result_list`
result_arr = напишить код ...

# %%
# побудувати словник для результатів аналізу
result_dict = {
    "кількість спостережень"   : напишить код ... ,
    "середнє значення"         : напишить код ... ,
    "максимальне значення"     : напишить код ... ,
    "мінімальне значення"      : напишить код ... ,
    "стандартне відхилення"    : напишить код ... ,
    "розмах вариації"          : напишить код ...
    }

# %%
# вивести шапку
print(
"""
================================================
№  :   РАЙОН        : ПОКАЗЧИК        : ЗНАЧЕННЯ     
================================================
"""      
      )

# вивести результати аналізу датасета
напишить код ...

# %%
import numpy as np

# створити np-масив з списку `result_list`
result_arr = np.array(result_list)

#print(type (result_arr), result_arr.shape)

test_result = np.delete(result_arr, [0,1],1)

#print(test_result)

test_result[test_result == None] = 0

#print(test_result)

# побудувати словник для результатів аналізу
result_dict = {
    "кількість спостережень"   : len(test_result),
    "середнє значення"         : round(np.mean(test_result),1),
    "максимальне значення"     : np.max(test_result),
    "мінімальне значення"      : np.min(test_result[np.nonzero(test_result)]),
    "стандартне відхилення"    : round(np.std(test_result),1),
    "розмах вариації"          : np.max(test_result) - np.min(test_result[np.nonzero(test_result)]) 
    }

# вивести шапку
print(
"""
================================================
№  :   РАЙОН        : ПОКАЗЧИК        : ЗНАЧЕННЯ     
================================================
"""      
      )

# вивести результати аналізу датасета
i = 1
for key, value in result_dict.items():
    print (f'{i:<3} {key:<25}  {value}')
    i += 1
# Out:
# <class 'numpy.ndarray'> (1622, 3)
#
# ================================================
# №  :   РАЙОН        : ПОКАЗЧИК        : ЗНАЧЕННЯ
# ================================================
#
# 1   кількість спостережень     1622
# 2   середнє значення           69.9
# 3   максимальне значення       555
# 4   мінімальне значення        22
# 5   стандартне відхилення      57.5
# 6   розмах вариації            533
